# %% [markdown]
# # Determining value of a car using historical data
# Rusty Bargain used car sales service is developing an app to attract new customers. In that app, you can quickly find out the market value of your car. You have access to historical data: technical specifications, trim versions, and prices. You need to build the model to determine the value.
#
# Rusty Bargain is interested in:
#
# - the quality of the prediction;
# - the speed of the prediction;
# - the time required for training

# %% [markdown]
# # Table of Contents
# 1. [General Information](#step1)
# 2. [Data Preprocessing](#step2)
# 3. [Model Training](#step3)
#   - [Linear Regression](#step3_1)
#   - [Decision Tree](#step3_2)
#   - [Random Forest](#step3_3)
#   - [CatBoost](#step3_4)
#   - [LightGBM](#step3_5)
# 4. [Model Analysis](#step4)
# 5. [Conclusion](#step5)

# %% [markdown]
# # General Information<a name='step1'></a>

# %% [markdown]
# Let us import our necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
import time
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
random_state=12345

# %% [markdown]
# We can now read our data

# %%
data=pd.read_csv('/datasets/car_data.csv')#reads the csv data as a pandas dataframe
data.head()#1st 5 rows
# Out:
#         DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  24/03/2016 11:52    480         NaN              1993  manual      0
# 1  24/03/2016 10:58  18300       coupe              2011  manual    190
# 2  14/03/2016 12:52   9800         suv              2004    auto    163
# 3  17/03/2016 16:54   1500       small              2001  manual     75
# 4  31/03/2016 17:25   3600       small              2008  manual     69
#
#    Model  Mileage  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0   golf   150000                  0    petrol  volkswagen         NaN
# 1    NaN   125000                  5  gasoline        audi         yes
# 2  grand   125000                  8  gasoline        jeep         NaN
# 3   golf   150000                  6    petrol  volkswagen          no
# 4  fabia    90000                  7  gasoline       skoda          no
#
#         DateCreated  NumberOfPictures  PostalCode          LastSeen
# 0  24/03/2016 00:00                 0       70435  07/04/2016 03:16
# 1  24/03/2016 00:00                 0       66954  07/04/2016 01:46
# 2  14/03/2016 00:00                 0       90480  05/04/2016 12:47
# 3  17/03/2016 00:00                 0       91074  17/03/2016 17:40
# 4  31/03/2016 00:00                 0       60437  06/04/2016 10:17

# %% [markdown]
# Let us get some general information about the dataframe

# %%
data.info()#general information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %% [markdown]
# Some rows have missing values that we will have to deal with. Let us look at a description of the numerical columns

# %%
data.describe()#description of columns with numerical values
# Out:
#                Price  RegistrationYear          Power        Mileage  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %% [markdown]
# A few things we can gather:
# 1. There price values of zero. This doesn't make sense. We need to filter those out.
# 2. There are registration years that date as far back as the year 1000, and as far into the future as the year 9999. According to history, the automobile was invented in 1886; and last time we checked, we are in the year 2021. Filtering is needed again
# 3. There are cars with zero power. This doesn't make sense. Filtering, again, is needed
# 4. Months go from 1 to 12. But we have values of 0 in the RegistrationMonth column. More filtering.
# 5. The NumberOfPictures column is zero all through. We can drop the whole column since that isn't helpful.

# %% [markdown]
# # Data Preprocessing<a name='step2'></a>

# %% [markdown]
# Let us check for duplicate rows. If we have any, we also need to drop those

# %%
data.duplicated().sum()#gives us the number of duplicate rows
# Out:
# 262

# %% [markdown]
# We can now start our cleaning process:

# %%
data=data[data['Price']!=0]#prices are not zero
data=data[data['Power']!=0]#no zero horsepower
data=data[data['RegistrationMonth']!=0]#no zero registration month
data=data[(1886 <= data['RegistrationYear']) & (data['RegistrationYear'] <= 2021)]
#registration is between and including 1886 and 2021
data=data.drop('NumberOfPictures', axis=1)#drops NumberOfPictures column
data['NotRepaired'].fillna(value='unknown', inplace=True)
#replace missing values in NotRepaired column by 'unknown' 
data.dropna(inplace=True)#drops all other missing values
data.drop_duplicates(inplace=True)#drop duplicate rows
data.info()#general info after changes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 253566 entries, 2 to 354368
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        253566 non-null  object
#  1   Price              253566 non-null  int64
#  2   VehicleType        253566 non-null  object
#  3   RegistrationYear   253566 non-null  int64
#  4   Gearbox            253566 non-null  object
#  5   Power              253566 non-null  int64
#  6   Model              253566 non-null  object
#  7   Mileage            253566 non-null  int64
#  8   RegistrationMonth  253566 non-null  int64
#  9   FuelType           253566 non-null  object
#  10  Brand              253566 non-null  object
#  11  NotRepaired        253566 non-null  object
#  12  DateCreated        253566 non-null  object
#  13  PostalCode         253566 non-null  int64
#  14  LastSeen           253566 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 31.0+ MB

# %% [markdown]
# We have finished our cleaning process. Now let us prepare the data splits. We will be training Linear Regression (as a baseline), Decision Tree Regressor, Random Forest Regressor, CatBoost Regressor, and LightGBM Regressor models. The first three models will need us to encode the categorical features prior to training. The last 2 don't need prior encoding since they have built-in encoders. So we will make 2 copies of our cleaned data: 1 that isn't encoded (which will be used with CatBoost and LightGBM), and the other which will be encoded for the other models. First, the data that will remain unencoded....

# %%
#creating and preparing a copy of data to use with CatBoost and LightGBM which don't need prior encoding
data_gbm=data.copy()#makes a copy of our cleaned data
data_gbm.drop(['DateCrawled', 'DateCreated', 'LastSeen'], axis=1, inplace=True)
#drops the columns that are in time-date format 
data_gbm.reset_index(drop=True, inplace=True)
#resets the index
f_gbm=data_gbm.drop('Price', axis=1)#defines our features
t_gbm=data_gbm['Price']#defines the price column as our target
f_train_gbm, f_test_gbm, t_train_gbm, t_test_gbm=train_test_split(f_gbm, t_gbm, test_size=0.2,
                                                                 random_state=random_state)
#splits our new data into training and test sets for our features and target

#prints the shapes of our splits
print(f_train_gbm.shape)
print(t_train_gbm.shape)
print(f_test_gbm.shape)
print(t_test_gbm.shape)
# Out:
# (202852, 11)
# (202852,)
# (50714, 11)
# (50714,)

# %% [markdown]
# Now for the encoded copy, we will first create a list with our columns we want encoded:

# %%
cat_feat=['VehicleType', 'RegistrationYear', 'Gearbox', 'Model', 'RegistrationMonth',
         'FuelType', 'Brand', 'NotRepaired', 'PostalCode']

# %%
#creating and preparing a copy of data to use with models requiring prior encoding
data_enc=data.copy()#copy of cleaned data
encoder=OrdinalEncoder()#creates an instance of the ordinal encoder
data_enc[cat_feat]=encoder.fit_transform(data_enc[cat_feat])#encodes the columns

# %%
#preparation and splitting for encoded data
data_enc.drop(['DateCrawled', 'DateCreated', 'LastSeen'], axis=1, inplace=True)
data_enc.reset_index(drop=True, inplace=True)
f_enc=data_enc.drop('Price', axis=1)
t_enc=data_enc['Price']
f_train_enc, f_test_enc, t_train_enc, t_test_enc=train_test_split(f_enc, t_enc, test_size=0.2,
                                                                 random_state=random_state)
print(f_train_enc.shape)
print(t_train_enc.shape)
print(f_test_enc.shape)
print(t_test_enc.shape)
# Out:
# (202852, 11)
# (202852,)
# (50714, 11)
# (50714,)

# %% [markdown]
# We have successfully cleaned and prepared encoded and unencoded data for model training

# %% [markdown]
# # Model training<a name='step3'></a>

# %% [markdown]
# We will first create a function to calculate the RMSE and then make it our evaluation metric (or scorer) for our models. It takes as arguments the prediction and target data.

# %%
#create an rmse function and make it our scorer
def rmse(pred, target):#creates the rmse function that takes target and prediction values as arguments
    pred=np.array(pred)#turns the prediction into a vector
    target=np.array(target)#turns the target into a vector
    error=pred - target #calculates the vector of errors
    sq_error=error ** 2 #squares the errors
    msq_error= sq_error.mean()#gets the mean of all errors
    score = msq_error ** 0.5 #gets the square root
    return score #returns the value
scorer=make_scorer(rmse, greater_is_better=False) 
#makes our rmse function our scorer and specifies that a smaller value is better

# %% [markdown]
# ## Linear Regression (Baseline)<a name='step3_1'></a>

# %% [markdown]
# We will now train a Linear Regression model as our baseline i.e the value of the evaluation metric (RMSE) that we will get from it will be the one that the other models should strive to beat. We will feed it the encoded data. Let's get a cross-validation score:

# %%
#Baseline model with Linear Regression
LR=LinearRegression()#creates an instance of Linear Regression model
LR_score=cross_val_score(LR, f_train_enc, t_train_enc, scoring=scorer, cv=5)
#calculates the cross-validation scores for 5 folds of the training data
print(LR_score.mean()) #prints the mean of those scores
# Out:
# -3341.572814146216

# %% [markdown]
# Let us train the model and take note of the wall time it takes to do so

# %%
#training LR model
LR=LinearRegression()#instance of a linear regression model
# %time LR.fit(f_train_enc, t_train_enc)#trains the model with the encoded data and times the process
# Out:
# CPU times: user 97.4 ms, sys: 59.9 ms, total: 157 ms
# Wall time: 130 ms
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# We now get predictions:

# %%
#LR model prediction
# %time lr_pred=LR.predict(f_test_enc)#gets predictions and times the process
# Out:
# CPU times: user 8.49 ms, sys: 19.5 ms, total: 28 ms
# Wall time: 66.7 ms

# %% [markdown]
# RMSE calculation:

# %%
#LR model RMSE
lr_rmse=rmse(t_test_enc, lr_pred)
lr_rmse
# Out:
# 3319.945019855772

# %% [markdown]
# So the RMSE of 3319.94 is the value to beat

# %% [markdown]
# ## Decision Tree Regressor<a name='step3_2'></a>

# %% [markdown]
# For this we will perform hyperparameter tuning (with the max_depth hyperparameter) to find its best value to set it to when actually training. We will choose the hyperparameter which gets the best cross-validation score

# %%
#Decision Tree Rgressor - hyperparameter tuning
for depth in range(1, 16):#loops through values of max_depth from 1 to 15
    DTR=DecisionTreeRegressor(max_depth=depth, random_state=random_state)
    #creates an instance of Decision Tree Rgressor model with the max_depth value and random state of 12345
    DTR_score=cross_val_score(DTR, f_train_enc, t_train_enc, scoring=scorer, cv=5)
    #gets cross-validation score
    print('Max_depth', depth, 'score:', DTR_score.mean())
    #prints max_depth value and the mean cross-validation score
# Out:
# Max_depth 1 score: -3597.5212621009646
# Max_depth 2 score: -3148.7614173370557
# Max_depth 3 score: -2791.439807061578
# Max_depth 4 score: -2541.7368659693166
# Max_depth 5 score: -2372.5274016078033
# Max_depth 6 score: -2263.1348897390744
# Max_depth 7 score: -2164.109806596397
# Max_depth 8 score: -2081.064381108975
# Max_depth 9 score: -2009.1902263310585
# Max_depth 10 score: -1951.205002133464
# Max_depth 11 score: -1913.3661189015081
# Max_depth 12 score: -1889.1937156659264
# Max_depth 13 score: -1882.4974472277943
# Max_depth 14 score: -1889.0048759830315
# Max_depth 15 score: -1911.4468913132223

# %% [markdown]
# So the best score was gotten when the max_depth hyperparameter was 13. So we will use that to train our model and get predictions, and the processes will be timed

# %%
#DTR model training
DTR=DecisionTreeRegressor(max_depth=13, random_state=random_state)
# %time DTR.fit(f_train_enc, t_train_enc)
# Out:
# CPU times: user 1.07 s, sys: 28 µs, total: 1.07 s
# Wall time: 1.09 s
# DecisionTreeRegressor(criterion='mse', max_depth=13, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=12345, splitter='best')

# %%
#DTR model prediction
# %time DTR_pred=DTR.predict(f_test_enc)
# Out:
# CPU times: user 13.7 ms, sys: 0 ns, total: 13.7 ms
# Wall time: 12.5 ms

# %% [markdown]
# RMSE calculation:

# %%
#DTR rmse
DTR_rmse=rmse(t_test_enc, DTR_pred)
DTR_rmse
# Out:
# 1855.542228750032

# %% [markdown]
# The RMSE is 1855.54 which is already much better than our baseline

# %% [markdown]
# ## Random Forest Regressor<a name='step3_3'></a>

# %% [markdown]
# Here we will perform hyperparameter tuning with 2 hyperparameters: max_depth and n_estimators. After doing so, the best model we came up with had n_estimators=70 and max_depth=24

# %%
#Random Forest Regressor - hyperparameter tuning
for depth in range(20, 26):
    RFR=RandomForestRegressor(n_estimators=70, max_depth=depth, random_state=random_state)
    RFR_score=cross_val_score(RFR, f_train_enc, t_train_enc, scoring=scorer, cv=5)
    print('Max_depth', depth, 'score:', RFR_score.mean())
# Out:
# Max_depth 20 score: -1551.1765036303507
# Max_depth 21 score: -1549.600091494261
# Max_depth 22 score: -1548.4409216471856
# Max_depth 23 score: -1547.4262950780078
# Max_depth 24 score: -1547.294733299153
# Max_depth 25 score: -1547.4023074095205

# %% [markdown]
# So let us train and test our model, with the processes being timed

# %%
#RFR model training
RFR=RandomForestRegressor(n_estimators=70, max_depth=24, random_state=random_state)
# %time RFR.fit(f_train_enc, t_train_enc)
# Out:
# CPU times: user 1min 11s, sys: 524 ms, total: 1min 12s
# Wall time: 1min 13s
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=24,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=70,
#                       n_jobs=None, oob_score=False, random_state=12345,
#                       verbose=0, warm_start=False)

# %%
#RFR model predictions
# %time RFR_pred=RFR.predict(f_test_enc)
# Out:
# CPU times: user 1.86 s, sys: 26 µs, total: 1.86 s
# Wall time: 1.98 s

# %% [markdown]
# RMSE calculation:

# %%
RFR_rmse=rmse(t_test_enc, RFR_pred)
RFR_rmse
# Out:
# 1527.8930336833093

# %% [markdown]
# RMSE of 1527. Much better than our baseline

# %% [markdown]
# ## CatBoost Regressor<a name='step3_4'></a>

# %% [markdown]
# For our CatBoost regressor (which uses gradient boosting), we don't need prior encoding. We will be tuning using different hyperparameters this time. We will find the best parameters using GridSearchCV.

# %%
#CatBoost - hyperparameter tuning
CBR=CatBoostRegressor()#instance of CatBoost Regressor
parameters={'depth': [6, 8, 10],
           'learning_rate': [0.5, 0.1],
           'l2_leaf_reg': [2, 4],
           'iterations': [10, 50],
           'loss_function': ['RMSE'],
           'random_seed': [random_state]}
#our dictionary of hyperparameters that will be looped through when we feed them to GridSearch
grid=GridSearchCV(estimator=CBR, param_grid=parameters, scoring=scorer, cv=3, n_jobs=-1, verbose=0)
#loops through parameters to help us get the best hyperparameters for model training
grid.fit(f_train_gbm, t_train_gbm, cat_features=cat_feat)
#fits our training unencoded data into our grid instance
best_param=grid.best_params_ #gets the best set of parameters for our model
# Out:
# 0:	learn: 3243.2208729	total: 346ms	remaining: 3.12s
# 1:	learn: 2550.6756245	total: 646ms	remaining: 2.58s
# 2:	learn: 2245.5139470	total: 942ms	remaining: 2.2s
# 3:	learn: 2093.2119517	total: 1.24s	remaining: 1.85s
# 4:	learn: 1999.0158196	total: 1.44s	remaining: 1.44s
# 5:	learn: 1952.1274484	total: 1.74s	remaining: 1.16s
# 6:	learn: 1923.2631983	total: 2.03s	remaining: 871ms
# 7:	learn: 1900.1347922	total: 2.24s	remaining: 560ms
# 8:	learn: 1878.0977223	total: 2.53s	remaining: 281ms
# 9:	learn: 1866.6032357	total: 2.74s	remaining: 0us
# 0:	learn: 3198.9719744	total: 272ms	remaining: 2.44s
# 1:	learn: 2545.9847100	total: 572ms	remaining: 2.29s
# 2:	learn: 2235.5128702	total: 872ms	remaining: 2.03s
# 3:	learn: 2087.9789974	total: 1.17s	remaining: 1.75s
# 4:	learn: 2016.7188869	total: 1.38s	remaining: 1.38s
# 5:	learn: 1963.7703900	total: 1.67s	remaining: 1.11s
# 6:	learn: 1930.9555137	total: 1.87s	remaining: 803ms
# 7:	learn: 1907.7143636	total: 2.17s	remaining: 542ms
# 8:	learn: 1883.7370442	total: 2.37s	remaining: 264ms
# 9:	learn: 1869.1904629	total: 2.66s	remaining: 0us
# 0:	learn: 3218.7788848	total: 296ms	remaining: 2.66s
# 1:	learn: 2512.6626469	total: 594ms	remaining: 2.38s
# 2:	learn: 2216.5052595	total: 800ms	remaining: 1.87s
# 3:	learn: 2072.8477183	total: 1.1s	remaining: 1.65s
# 4:	learn: 1999.0243511	total: 1.39s	remaining: 1.39s
# 5:	learn: 1957.6578355	total: 1.6s	remaining: 1.07s
# 6:	learn: 1922.0068224	total: 1.89s	remaining: 811ms
# 7:	learn: 1896.0805109	total: 2.1s	remaining: 524ms
# 8:	learn: 1876.0667499	total: 2.39s	remaining: 265ms
# 9:	learn: 1862.4389117	total: 2.6s	remaining: 0us
# 0:	learn: 4368.7636718	total: 233ms	remaining: 2.1s
# 1:	learn: 4084.5259586	total: 532ms	remaining: 2.13s
# 2:	learn: 3827.4004215	total: 739ms	remaining: 1.72s
# 3:	learn: 3603.3340498	total: 1.03s	remaining: 1.54s
# 4:	learn: 3400.2420695	total: 1.24s	remaining: 1.24s
# 5:	learn: 3223.8275516	total: 1.53s	remaining: 1.02s
# 6:	learn: 3063.4051673	total: 1.83s	remaining: 783ms
# 7:	learn: 2929.7630720	total: 2.03s	remaining: 508ms
# 8:	learn: 2807.5609283	total: 2.33s	remaining: 259ms
# 9:	learn: 2700.8737065	total: 2.53s	remaining: 0us
# 0:	learn: 4357.9278349	total: 200ms	remaining: 1.8s
# 1:	learn: 4073.8747084	total: 497ms	remaining: 1.99s
# 2:	learn: 3822.6850341	total: 797ms	remaining: 1.86s
# 3:	learn: 3598.3405429	total: 1.09s	remaining: 1.63s
# 4:	learn: 3403.4129568	total: 1.29s	remaining: 1.29s
# 5:	learn: 3226.5950531	total: 1.59s	remaining: 1.06s
# 6:	learn: 3074.8675716	total: 1.8s	remaining: 771ms
# 7:	learn: 2935.3214102	total: 2.09s	remaining: 522ms
# 8:	learn: 2813.9459512	total: 2.29s	remaining: 254ms
# 9:	learn: 2707.0366274	total: 2.58s	remaining: 0us
# 0:	learn: 4363.5557197	total: 286ms	remaining: 2.58s
# 1:	learn: 4073.4797704	total: 586ms	remaining: 2.34s
# 2:	learn: 3817.4601127	total: 795ms	remaining: 1.85s
# 3:	learn: 3594.6632821	total: 1.08s	remaining: 1.63s
# 4:	learn: 3396.5937348	total: 1.29s	remaining: 1.29s
# 5:	learn: 3221.9060142	total: 1.59s	remaining: 1.06s
# 6:	learn: 3065.8888552	total: 1.88s	remaining: 807ms
# 7:	learn: 2929.8607441	total: 2.09s	remaining: 522ms
# 8:	learn: 2804.1224495	total: 2.38s	remaining: 265ms
# 9:	learn: 2696.6740741	total: 2.59s	remaining: 0us
# 0:	learn: 3244.0965105	total: 250ms	remaining: 2.25s
# 1:	learn: 2551.5769452	total: 462ms	remaining: 1.85s
# 2:	learn: 2246.2253829	total: 755ms	remaining: 1.76s
# 3:	learn: 2094.1465347	total: 1.05s	remaining: 1.57s
# 4:	learn: 1999.8884430	total: 1.25s	remaining: 1.25s
# 5:	learn: 1952.9724941	total: 1.55s	remaining: 1.03s
# 6:	learn: 1924.0869847	total: 1.75s	remaining: 751ms
# 7:	learn: 1901.0830532	total: 2.05s	remaining: 512ms
# 8:	learn: 1879.0387111	total: 2.25s	remaining: 250ms
# 9:	learn: 1867.6466269	total: 2.55s	remaining: 0us
# 0:	learn: 3199.7052087	total: 258ms	remaining: 2.32s
# 1:	learn: 2547.2253570	total: 557ms	remaining: 2.23s
# 2:	learn: 2230.9940544	total: 765ms	remaining: 1.78s
# 3:	learn: 2081.8861270	total: 1.06s	remaining: 1.59s
# 4:	learn: 2010.8836485	total: 1.35s	remaining: 1.35s
# 5:	learn: 1962.3569319	total: 1.56s	remaining: 1.04s
# 6:	learn: 1939.0959898	total: 1.85s	remaining: 794ms
# 7:	learn: 1913.5664976	total: 2.06s	remaining: 515ms
# 8:	learn: 1895.6787175	total: 2.35s	remaining: 261ms
# 9:	learn: 1874.9573626	total: 2.56s	remaining: 0us
# 0:	learn: 3219.6548705	total: 277ms	remaining: 2.5s
# 1:	learn: 2513.6955489	total: 580ms	remaining: 2.32s
# 2:	learn: 2217.3031867	total: 877ms	remaining: 2.04s
# 3:	learn: 2073.8954011	total: 1.18s	remaining: 1.76s
# 4:	learn: 1999.5993659	total: 1.39s	remaining: 1.39s
# 5:	learn: 1958.5429885	total: 1.68s	remaining: 1.12s
# 6:	learn: 1923.1747669	total: 1.97s	remaining: 845ms
# 7:	learn: 1897.2350493	total: 2.18s	remaining: 544ms
# 8:	learn: 1877.2859384	total: 2.47s	remaining: 274ms
# 9:	learn: 1863.6980793	total: 2.67s	remaining: 0us
# 0:	learn: 4368.9969582	total: 249ms	remaining: 2.24s
# 1:	learn: 4084.8909166	total: 456ms	remaining: 1.82s
# 2:	learn: 3827.9102976	total: 751ms	remaining: 1.75s
# 3:	learn: 3603.9405760	total: 956ms	remaining: 1.43s
# 4:	learn: 3400.9355183	total: 1.25s	remaining: 1.25s
# 5:	learn: 3224.6648767	total: 1.55s	remaining: 1.03s
# 6:	learn: 3064.2828081	total: 1.75s	remaining: 750ms
# 7:	learn: 2930.6676293	total: 2.04s	remaining: 511ms
# 8:	learn: 2808.4631892	total: 2.25s	remaining: 250ms
# 9:	learn: 2701.7609495	total: 2.54s	remaining: 0us
# 0:	learn: 4358.1145490	total: 242ms	remaining: 2.18s
# 1:	learn: 4074.1563457	total: 457ms	remaining: 1.83s
# 2:	learn: 3823.2246504	total: 840ms	remaining: 1.96s
# 3:	learn: 3598.9904089	total: 1.04s	remaining: 1.57s
# 4:	learn: 3404.1386185	total: 1.34s	remaining: 1.34s
# 5:	learn: 3227.3668499	total: 1.55s	remaining: 1.03s
# 6:	learn: 3075.6726815	total: 1.84s	remaining: 790ms
# 7:	learn: 2936.1653086	total: 2.13s	remaining: 534ms
# 8:	learn: 2814.8614428	total: 2.34s	remaining: 260ms
# 9:	learn: 2707.9686891	total: 2.63s	remaining: 0us
# 0:	learn: 4363.7875439	total: 142ms	remaining: 1.27s
# 1:	learn: 4073.8263755	total: 443ms	remaining: 1.77s
# 2:	learn: 3817.9308621	total: 738ms	remaining: 1.72s
# 3:	learn: 3595.2537941	total: 1.03s	remaining: 1.55s
# 4:	learn: 3397.2657431	total: 1.33s	remaining: 1.33s
# 5:	learn: 3222.7646635	total: 1.54s	remaining: 1.02s
# 6:	learn: 3066.7630955	total: 1.83s	remaining: 784ms
# 7:	learn: 2930.7491084	total: 2.04s	remaining: 510ms
# 8:	learn: 2805.0571156	total: 2.33s	remaining: 259ms
# 9:	learn: 2697.5809944	total: 2.62s	remaining: 0us
# 0:	learn: 3243.2208729	total: 226ms	remaining: 11.1s
# 1:	learn: 2550.6756245	total: 526ms	remaining: 12.6s
# 2:	learn: 2245.5139470	total: 824ms	remaining: 12.9s
# 3:	learn: 2093.2119517	total: 1.03s	remaining: 11.8s
# 4:	learn: 1999.0158196	total: 1.32s	remaining: 11.9s
# 5:	learn: 1952.1274484	total: 1.53s	remaining: 11.2s
# 6:	learn: 1923.2631983	total: 1.82s	remaining: 11.2s
# 7:	learn: 1900.1347922	total: 2.12s	remaining: 11.1s
# 8:	learn: 1878.0977223	total: 2.33s	remaining: 10.6s
# 9:	learn: 1866.6032357	total: 2.62s	remaining: 10.5s
# 10:	learn: 1847.0774173	total: 2.83s	remaining: 10s
# 11:	learn: 1831.7580069	total: 3.12s	remaining: 9.87s
# 12:	learn: 1820.6861125	total: 3.32s	remaining: 9.45s
# 13:	learn: 1811.2437934	total: 3.61s	remaining: 9.29s
# 14:	learn: 1804.0897254	total: 3.82s	remaining: 8.91s
# 15:	learn: 1794.0630261	total: 4.11s	remaining: 8.74s
# 16:	learn: 1786.9865462	total: 4.32s	remaining: 8.38s
# 17:	learn: 1783.1248238	total: 4.61s	remaining: 8.2s
# 18:	learn: 1775.6807088	total: 4.82s	remaining: 7.86s
# 19:	learn: 1772.8133195	total: 5.11s	remaining: 7.67s
# 20:	learn: 1761.9442133	total: 5.32s	remaining: 7.34s
# 21:	learn: 1757.4238187	total: 5.61s	remaining: 7.14s
# 22:	learn: 1746.4830417	total: 5.82s	remaining: 6.83s
# 23:	learn: 1741.9962817	total: 6.11s	remaining: 6.62s
# 24:	learn: 1737.0389342	total: 6.31s	remaining: 6.31s
# 25:	learn: 1733.5421152	total: 6.61s	remaining: 6.1s
# 26:	learn: 1729.7668110	total: 6.81s	remaining: 5.8s
# 27:	learn: 1724.9464367	total: 7.1s	remaining: 5.58s
# 28:	learn: 1720.7675039	total: 7.31s	remaining: 5.29s
# 29:	learn: 1717.3178874	total: 7.6s	remaining: 5.07s
# 30:	learn: 1712.2862801	total: 7.82s	remaining: 4.79s
# 31:	learn: 1707.1073938	total: 8.1s	remaining: 4.56s
# 32:	learn: 1704.7209318	total: 8.31s	remaining: 4.28s
# 33:	learn: 1700.3892163	total: 8.6s	remaining: 4.05s
# 34:	learn: 1696.9515840	total: 8.81s	remaining: 3.77s
# 35:	learn: 1693.6442954	total: 9.1s	remaining: 3.54s
# 36:	learn: 1690.5741927	total: 9.3s	remaining: 3.27s
# 37:	learn: 1688.9825193	total: 9.6s	remaining: 3.03s
# 38:	learn: 1687.4679493	total: 9.8s	remaining: 2.77s
# 39:	learn: 1684.6784007	total: 10.1s	remaining: 2.52s
# 40:	learn: 1682.6901996	total: 10.3s	remaining: 2.26s
# 41:	learn: 1680.1300275	total: 10.6s	remaining: 2.02s
# 42:	learn: 1677.2574945	total: 10.8s	remaining: 1.76s
# 43:	learn: 1675.2346989	total: 11.1s	remaining: 1.51s
# 44:	learn: 1672.6355214	total: 11.3s	remaining: 1.25s
# 45:	learn: 1670.1326258	total: 11.6s	remaining: 1.01s
# 46:	learn: 1665.5281712	total: 11.8s	remaining: 753ms
# 47:	learn: 1662.6306521	total: 12s	remaining: 500ms
# 48:	learn: 1660.1221724	total: 12.3s	remaining: 251ms
# 49:	learn: 1657.8998759	total: 12.6s	remaining: 0us
# 0:	learn: 3198.9719744	total: 253ms	remaining: 12.4s
# 1:	learn: 2545.9847100	total: 553ms	remaining: 13.3s
# 2:	learn: 2235.5128702	total: 852ms	remaining: 13.3s
# 3:	learn: 2087.9789974	total: 1.06s	remaining: 12.2s
# 4:	learn: 2016.7188869	total: 1.35s	remaining: 12.2s
# 5:	learn: 1963.7703900	total: 1.65s	remaining: 12.1s
# 6:	learn: 1930.9555137	total: 1.86s	remaining: 11.4s
# 7:	learn: 1907.7143636	total: 2.15s	remaining: 11.3s
# 8:	learn: 1883.7370442	total: 2.36s	remaining: 10.7s
# 9:	learn: 1869.1904629	total: 2.65s	remaining: 10.6s
# 10:	learn: 1850.5685309	total: 2.85s	remaining: 10.1s
# 11:	learn: 1835.3684140	total: 3.15s	remaining: 9.97s
# 12:	learn: 1824.5690956	total: 3.35s	remaining: 9.54s
# 13:	learn: 1812.8918949	total: 3.64s	remaining: 9.37s
# 14:	learn: 1804.4497544	total: 3.86s	remaining: 9s
# 15:	learn: 1795.3308367	total: 4.14s	remaining: 8.8s
# 16:	learn: 1785.3157286	total: 4.44s	remaining: 8.62s
# 17:	learn: 1777.7352616	total: 4.64s	remaining: 8.26s
# 18:	learn: 1772.2237122	total: 4.94s	remaining: 8.06s
# 19:	learn: 1764.0427247	total: 5.15s	remaining: 7.72s
# 20:	learn: 1759.6621772	total: 5.44s	remaining: 7.51s
# 21:	learn: 1754.3159935	total: 5.73s	remaining: 7.29s
# 22:	learn: 1747.5822730	total: 5.94s	remaining: 6.97s
# 23:	learn: 1743.7517132	total: 6.23s	remaining: 6.75s
# 24:	learn: 1737.4941652	total: 6.44s	remaining: 6.44s
# 25:	learn: 1733.8199791	total: 6.64s	remaining: 6.13s
# 26:	learn: 1726.5290643	total: 6.93s	remaining: 5.91s
# 27:	learn: 1722.8621414	total: 7.14s	remaining: 5.61s
# 28:	learn: 1716.6448971	total: 7.43s	remaining: 5.38s
# 29:	learn: 1711.9855546	total: 7.64s	remaining: 5.09s
# 30:	learn: 1708.9149949	total: 7.93s	remaining: 4.86s
# 31:	learn: 1706.4536519	total: 8.13s	remaining: 4.58s
# 32:	learn: 1702.1951533	total: 8.43s	remaining: 4.34s
# 33:	learn: 1698.3539008	total: 8.63s	remaining: 4.06s
# 34:	learn: 1695.0552940	total: 8.93s	remaining: 3.83s
# 35:	learn: 1693.3094541	total: 9.13s	remaining: 3.55s
# 36:	learn: 1691.0883893	total: 9.42s	remaining: 3.31s
# 37:	learn: 1688.5371162	total: 9.63s	remaining: 3.04s
# 38:	learn: 1686.4319465	total: 9.93s	remaining: 2.8s
# 39:	learn: 1683.3684830	total: 10.1s	remaining: 2.54s
# 40:	learn: 1679.7931318	total: 10.4s	remaining: 2.29s
# 41:	learn: 1678.3559188	total: 10.6s	remaining: 2.02s
# 42:	learn: 1674.1639284	total: 10.9s	remaining: 1.78s
# 43:	learn: 1672.0976508	total: 11.1s	remaining: 1.52s
# 44:	learn: 1669.4391881	total: 11.4s	remaining: 1.27s
# 45:	learn: 1667.4625423	total: 11.6s	remaining: 1.01s
# 46:	learn: 1664.7796966	total: 11.9s	remaining: 760ms
# 47:	learn: 1663.5531669	total: 12.1s	remaining: 505ms
# 48:	learn: 1662.3736929	total: 12.4s	remaining: 253ms
# 49:	learn: 1660.5063372	total: 12.6s	remaining: 0us
# 0:	learn: 3218.7788848	total: 256ms	remaining: 12.6s
# 1:	learn: 2512.6626469	total: 558ms	remaining: 13.4s
# 2:	learn: 2216.5052595	total: 852ms	remaining: 13.3s
# 3:	learn: 2072.8477183	total: 1.06s	remaining: 12.2s
# 4:	learn: 1999.0243511	total: 1.35s	remaining: 12.2s
# 5:	learn: 1957.6578355	total: 1.56s	remaining: 11.5s
# 6:	learn: 1922.0068224	total: 1.85s	remaining: 11.4s
# 7:	learn: 1896.0805109	total: 2.15s	remaining: 11.3s
# 8:	learn: 1876.0667499	total: 2.35s	remaining: 10.7s
# 9:	learn: 1862.4389117	total: 2.65s	remaining: 10.6s
# 10:	learn: 1849.2954036	total: 2.86s	remaining: 10.1s
# 11:	learn: 1831.2378233	total: 3.15s	remaining: 9.98s
# 12:	learn: 1819.3459887	total: 3.44s	remaining: 9.81s
# 13:	learn: 1811.0440271	total: 3.65s	remaining: 9.39s
# 14:	learn: 1800.7702153	total: 3.94s	remaining: 9.21s
# 15:	learn: 1795.2566555	total: 4.15s	remaining: 8.81s
# 16:	learn: 1772.7624031	total: 4.44s	remaining: 8.62s
# 17:	learn: 1767.1038213	total: 4.74s	remaining: 8.42s
# 18:	learn: 1761.6659315	total: 4.95s	remaining: 8.07s
# 19:	learn: 1750.3358437	total: 5.33s	remaining: 8s
# 20:	learn: 1742.4725968	total: 5.54s	remaining: 7.65s
# 21:	learn: 1737.6090211	total: 5.83s	remaining: 7.42s
# 22:	learn: 1732.4560900	total: 6.04s	remaining: 7.09s
# 23:	learn: 1726.9402676	total: 6.25s	remaining: 6.77s
# 24:	learn: 1723.5633029	total: 6.53s	remaining: 6.53s
# 25:	learn: 1717.8612846	total: 6.83s	remaining: 6.3s
# 26:	learn: 1714.5959654	total: 7.03s	remaining: 5.99s
# 27:	learn: 1710.0922500	total: 7.33s	remaining: 5.76s
# 28:	learn: 1706.9655062	total: 7.54s	remaining: 5.46s
# 29:	learn: 1702.7663285	total: 7.83s	remaining: 5.22s
# 30:	learn: 1699.2078729	total: 8.03s	remaining: 4.92s
# 31:	learn: 1694.5635179	total: 8.33s	remaining: 4.68s
# 32:	learn: 1690.5184888	total: 8.53s	remaining: 4.39s
# 33:	learn: 1683.1140787	total: 8.83s	remaining: 4.15s
# 34:	learn: 1678.2902390	total: 9.04s	remaining: 3.87s
# 35:	learn: 1674.7548572	total: 9.33s	remaining: 3.63s
# 36:	learn: 1671.4764020	total: 9.62s	remaining: 3.38s
# 37:	learn: 1669.6615300	total: 9.82s	remaining: 3.1s
# 38:	learn: 1667.2948032	total: 10.1s	remaining: 2.85s
# 39:	learn: 1665.8150438	total: 10.3s	remaining: 2.58s
# 40:	learn: 1661.7526445	total: 10.5s	remaining: 2.31s
# 41:	learn: 1659.6653188	total: 10.8s	remaining: 2.06s
# 42:	learn: 1655.5729375	total: 11s	remaining: 1.79s
# 43:	learn: 1653.9707699	total: 11.3s	remaining: 1.54s
# 44:	learn: 1651.0178289	total: 11.5s	remaining: 1.28s
# 45:	learn: 1649.6790338	total: 11.8s	remaining: 1.03s
# 46:	learn: 1646.5727698	total: 12s	remaining: 767ms
# 47:	learn: 1643.6999287	total: 12.3s	remaining: 513ms
# 48:	learn: 1641.8370818	total: 12.5s	remaining: 255ms
# 49:	learn: 1637.9592280	total: 12.8s	remaining: 0us
# 0:	learn: 4368.7636718	total: 269ms	remaining: 13.2s
# 1:	learn: 4084.5259586	total: 567ms	remaining: 13.6s
# 2:	learn: 3827.4004215	total: 773ms	remaining: 12.1s
# 3:	learn: 3603.3340498	total: 1.06s	remaining: 12.3s
# 4:	learn: 3400.2420695	total: 1.27s	remaining: 11.4s
# 5:	learn: 3223.8275516	total: 1.57s	remaining: 11.5s
# 6:	learn: 3063.4051673	total: 1.86s	remaining: 11.4s
# 7:	learn: 2929.7630720	total: 2.07s	remaining: 10.8s
# 8:	learn: 2807.5609283	total: 2.36s	remaining: 10.8s
# 9:	learn: 2700.8737065	total: 2.57s	remaining: 10.3s
# 10:	learn: 2605.9480476	total: 2.86s	remaining: 10.1s
# 11:	learn: 2522.3458844	total: 3.07s	remaining: 9.71s
# 12:	learn: 2448.0273126	total: 3.36s	remaining: 9.56s
# 13:	learn: 2381.7646029	total: 3.57s	remaining: 9.17s
# 14:	learn: 2323.7920477	total: 3.86s	remaining: 9.01s
# 15:	learn: 2272.2663745	total: 4.15s	remaining: 8.83s
# 16:	learn: 2229.1245981	total: 4.36s	remaining: 8.46s
# 17:	learn: 2191.7246609	total: 4.65s	remaining: 8.27s
# 18:	learn: 2157.8879200	total: 4.86s	remaining: 7.92s
# 19:	learn: 2126.6554018	total: 5.15s	remaining: 7.73s
# 20:	learn: 2098.4248833	total: 5.36s	remaining: 7.4s
# 21:	learn: 2075.7386636	total: 5.65s	remaining: 7.19s
# 22:	learn: 2051.0331099	total: 5.86s	remaining: 6.88s
# 23:	learn: 2029.4450494	total: 6.15s	remaining: 6.66s
# 24:	learn: 2012.9719562	total: 6.35s	remaining: 6.35s
# 25:	learn: 1997.2623152	total: 6.64s	remaining: 6.13s
# 26:	learn: 1983.9065300	total: 6.85s	remaining: 5.84s
# 27:	learn: 1972.8018312	total: 7.15s	remaining: 5.62s
# 28:	learn: 1960.8890879	total: 7.44s	remaining: 5.39s
# 29:	learn: 1949.2770919	total: 7.65s	remaining: 5.1s
# 30:	learn: 1939.8717668	total: 7.94s	remaining: 4.87s
# 31:	learn: 1930.6222293	total: 8.14s	remaining: 4.58s
# 32:	learn: 1922.4301929	total: 8.44s	remaining: 4.35s
# 33:	learn: 1915.1389969	total: 8.64s	remaining: 4.07s
# 34:	learn: 1909.3930341	total: 8.85s	remaining: 3.79s
# 35:	learn: 1901.5007775	total: 9.14s	remaining: 3.55s
# 36:	learn: 1892.6921699	total: 9.44s	remaining: 3.31s
# 37:	learn: 1883.1726604	total: 9.64s	remaining: 3.04s
# 38:	learn: 1876.8148952	total: 9.93s	remaining: 2.8s
# 39:	learn: 1870.7508142	total: 10.1s	remaining: 2.53s
# 40:	learn: 1864.7328717	total: 10.4s	remaining: 2.29s
# 41:	learn: 1859.2811160	total: 10.6s	remaining: 2.03s
# 42:	learn: 1854.6584626	total: 10.9s	remaining: 1.78s
# 43:	learn: 1850.6754642	total: 11.1s	remaining: 1.52s
# 44:	learn: 1846.8648457	total: 11.4s	remaining: 1.27s
# 45:	learn: 1843.3623032	total: 11.7s	remaining: 1.02s
# 46:	learn: 1839.1428204	total: 11.9s	remaining: 761ms
# 47:	learn: 1834.0158966	total: 12.2s	remaining: 509ms
# 48:	learn: 1830.8234322	total: 12.4s	remaining: 254ms
# 49:	learn: 1825.4737074	total: 12.6s	remaining: 0us
# 0:	learn: 4357.9278349	total: 235ms	remaining: 11.5s
# 1:	learn: 4073.8747084	total: 533ms	remaining: 12.8s
# 2:	learn: 3822.6850341	total: 833ms	remaining: 13s
# 3:	learn: 3598.3405429	total: 1.04s	remaining: 11.9s
# 4:	learn: 3403.4129568	total: 1.33s	remaining: 12s
# 5:	learn: 3226.5950531	total: 1.54s	remaining: 11.3s
# 6:	learn: 3074.8675716	total: 1.83s	remaining: 11.3s
# 7:	learn: 2935.3214102	total: 2.04s	remaining: 10.7s
# 8:	learn: 2813.9459512	total: 2.33s	remaining: 10.6s
# 9:	learn: 2707.0366274	total: 2.54s	remaining: 10.1s
# 10:	learn: 2615.2882074	total: 2.83s	remaining: 10s
# 11:	learn: 2531.3408270	total: 3.03s	remaining: 9.61s
# 12:	learn: 2457.9372830	total: 3.33s	remaining: 9.47s
# 13:	learn: 2393.3292521	total: 3.53s	remaining: 9.09s
# 14:	learn: 2335.7129874	total: 3.83s	remaining: 8.93s
# 15:	learn: 2286.9647008	total: 4.03s	remaining: 8.56s
# 16:	learn: 2241.7140857	total: 4.32s	remaining: 8.39s
# 17:	learn: 2201.5119759	total: 4.53s	remaining: 8.05s
# 18:	learn: 2166.2007818	total: 4.82s	remaining: 7.87s
# 19:	learn: 2134.7742223	total: 5.03s	remaining: 7.54s
# 20:	learn: 2107.3416194	total: 5.32s	remaining: 7.35s
# 21:	learn: 2083.1134692	total: 5.62s	remaining: 7.15s
# 22:	learn: 2060.3682637	total: 5.82s	remaining: 6.83s
# 23:	learn: 2040.3551347	total: 6.12s	remaining: 6.62s
# 24:	learn: 2024.7156211	total: 6.32s	remaining: 6.32s
# 25:	learn: 2007.4791326	total: 6.61s	remaining: 6.11s
# 26:	learn: 1992.4660125	total: 6.82s	remaining: 5.81s
# 27:	learn: 1980.6498366	total: 7.11s	remaining: 5.59s
# 28:	learn: 1969.0500490	total: 7.32s	remaining: 5.3s
# 29:	learn: 1956.7941610	total: 7.61s	remaining: 5.07s
# 30:	learn: 1943.8964624	total: 7.81s	remaining: 4.79s
# 31:	learn: 1935.2915122	total: 8.02s	remaining: 4.51s
# 32:	learn: 1927.1876432	total: 8.31s	remaining: 4.28s
# 33:	learn: 1917.2841572	total: 8.51s	remaining: 4.01s
# 34:	learn: 1910.3281331	total: 8.81s	remaining: 3.77s
# 35:	learn: 1903.8491516	total: 9.01s	remaining: 3.5s
# 36:	learn: 1895.3085900	total: 9.31s	remaining: 3.27s
# 37:	learn: 1888.2360711	total: 9.51s	remaining: 3s
# 38:	learn: 1882.1829066	total: 9.8s	remaining: 2.77s
# 39:	learn: 1875.4988003	total: 10s	remaining: 2.5s
# 40:	learn: 1870.3963110	total: 10.3s	remaining: 2.26s
# 41:	learn: 1864.3864375	total: 10.5s	remaining: 2s
# 42:	learn: 1859.8841393	total: 10.8s	remaining: 1.76s
# 43:	learn: 1854.6592484	total: 11s	remaining: 1.5s
# 44:	learn: 1850.9217382	total: 11.3s	remaining: 1.25s
# 45:	learn: 1847.6491486	total: 11.5s	remaining: 1s
# 46:	learn: 1844.8994159	total: 11.8s	remaining: 753ms
# 47:	learn: 1841.6287673	total: 12.1s	remaining: 504ms
# 48:	learn: 1838.2427280	total: 12.3s	remaining: 251ms
# 49:	learn: 1834.6798911	total: 12.6s	remaining: 0us
# 0:	learn: 4363.5557197	total: 221ms	remaining: 10.8s
# 1:	learn: 4073.4797704	total: 521ms	remaining: 12.5s
# 2:	learn: 3817.4601127	total: 736ms	remaining: 11.5s
# 3:	learn: 3594.6632821	total: 1.02s	remaining: 11.8s
# 4:	learn: 3396.5937348	total: 1.23s	remaining: 11.1s
# 5:	learn: 3221.9060142	total: 1.52s	remaining: 11.2s
# 6:	learn: 3065.8888552	total: 1.73s	remaining: 10.6s
# 7:	learn: 2929.8607441	total: 2.02s	remaining: 10.6s
# 8:	learn: 2804.1224495	total: 2.23s	remaining: 10.2s
# 9:	learn: 2696.6740741	total: 2.52s	remaining: 10.1s
# 10:	learn: 2599.4867644	total: 2.81s	remaining: 9.98s
# 11:	learn: 2516.0025475	total: 3.02s	remaining: 9.57s
# 12:	learn: 2440.9087473	total: 3.31s	remaining: 9.43s
# 13:	learn: 2376.4920491	total: 3.52s	remaining: 9.05s
# 14:	learn: 2319.7329340	total: 3.81s	remaining: 8.89s
# 15:	learn: 2268.3176852	total: 4.02s	remaining: 8.53s
# 16:	learn: 2223.7051713	total: 4.31s	remaining: 8.36s
# 17:	learn: 2185.2274858	total: 4.51s	remaining: 8.02s
# 18:	learn: 2149.6449068	total: 4.8s	remaining: 7.84s
# 19:	learn: 2120.0476357	total: 5.01s	remaining: 7.52s
# 20:	learn: 2092.5980217	total: 5.21s	remaining: 7.19s
# 21:	learn: 2066.7862596	total: 5.5s	remaining: 7s
# 22:	learn: 2044.1940197	total: 5.71s	remaining: 6.7s
# 23:	learn: 2024.4160648	total: 6s	remaining: 6.5s
# 24:	learn: 2006.9698007	total: 6.21s	remaining: 6.21s
# 25:	learn: 1990.2030597	total: 6.5s	remaining: 6s
# 26:	learn: 1975.6546992	total: 6.7s	remaining: 5.71s
# 27:	learn: 1962.3784929	total: 7s	remaining: 5.5s
# 28:	learn: 1950.6435957	total: 7.2s	remaining: 5.21s
# 29:	learn: 1938.1881888	total: 7.49s	remaining: 5s
# 30:	learn: 1928.4421685	total: 7.7s	remaining: 4.72s
# 31:	learn: 1920.3277048	total: 7.91s	remaining: 4.45s
# 32:	learn: 1912.0073414	total: 8.2s	remaining: 4.22s
# 33:	learn: 1903.2521726	total: 8.49s	remaining: 3.99s
# 34:	learn: 1896.1996618	total: 8.69s	remaining: 3.73s
# 35:	learn: 1890.9321117	total: 8.99s	remaining: 3.5s
# 36:	learn: 1883.6596210	total: 9.2s	remaining: 3.23s
# 37:	learn: 1876.0239065	total: 9.49s	remaining: 3s
# 38:	learn: 1868.5857529	total: 9.69s	remaining: 2.73s
# 39:	learn: 1859.8212502	total: 9.9s	remaining: 2.47s
# 40:	learn: 1854.3394399	total: 10.2s	remaining: 2.24s
# 41:	learn: 1848.6799717	total: 10.4s	remaining: 1.98s
# 42:	learn: 1843.3313470	total: 10.7s	remaining: 1.74s
# 43:	learn: 1839.1105764	total: 10.9s	remaining: 1.48s
# 44:	learn: 1835.3680853	total: 11.2s	remaining: 1.24s
# 45:	learn: 1832.1046537	total: 11.4s	remaining: 990ms
# 46:	learn: 1827.6057593	total: 11.7s	remaining: 746ms
# 47:	learn: 1822.6839910	total: 11.9s	remaining: 495ms
# 48:	learn: 1818.0024599	total: 12.2s	remaining: 249ms
# 49:	learn: 1814.4234558	total: 12.4s	remaining: 0us
# 0:	learn: 3244.0965105	total: 268ms	remaining: 13.1s
# 1:	learn: 2551.5769452	total: 568ms	remaining: 13.6s
# 2:	learn: 2246.2253829	total: 863ms	remaining: 13.5s
# 3:	learn: 2094.1465347	total: 1.07s	remaining: 12.3s
# 4:	learn: 1999.8884430	total: 1.36s	remaining: 12.3s
# 5:	learn: 1952.9724941	total: 1.66s	remaining: 12.2s
# 6:	learn: 1924.0869847	total: 1.87s	remaining: 11.5s
# 7:	learn: 1901.0830532	total: 2.17s	remaining: 11.4s
# 8:	learn: 1879.0387111	total: 2.37s	remaining: 10.8s
# 9:	learn: 1867.6466269	total: 2.66s	remaining: 10.6s
# 10:	learn: 1850.0090978	total: 2.95s	remaining: 10.5s
# 11:	learn: 1834.2083749	total: 3.16s	remaining: 10s
# 12:	learn: 1819.2429923	total: 3.45s	remaining: 9.83s
# 13:	learn: 1810.8459759	total: 3.66s	remaining: 9.41s
# 14:	learn: 1801.1706648	total: 3.95s	remaining: 9.22s
# 15:	learn: 1791.6727368	total: 4.16s	remaining: 8.83s
# 16:	learn: 1786.3381937	total: 4.45s	remaining: 8.64s
# 17:	learn: 1781.5320231	total: 4.66s	remaining: 8.28s
# 18:	learn: 1773.0125403	total: 4.95s	remaining: 8.08s
# 19:	learn: 1769.9723493	total: 5.15s	remaining: 7.73s
# 20:	learn: 1763.4031549	total: 5.45s	remaining: 7.53s
# 21:	learn: 1757.5133650	total: 5.74s	remaining: 7.31s
# 22:	learn: 1751.2393261	total: 5.95s	remaining: 6.98s
# 23:	learn: 1746.3171333	total: 6.24s	remaining: 6.76s
# 24:	learn: 1742.2918765	total: 6.45s	remaining: 6.45s
# 25:	learn: 1736.0903375	total: 6.74s	remaining: 6.22s
# 26:	learn: 1733.3366490	total: 6.94s	remaining: 5.92s
# 27:	learn: 1728.7212080	total: 7.24s	remaining: 5.69s
# 28:	learn: 1722.9519740	total: 7.44s	remaining: 5.39s
# 29:	learn: 1720.0294897	total: 7.74s	remaining: 5.16s
# 30:	learn: 1715.1692173	total: 7.94s	remaining: 4.87s
# 31:	learn: 1710.6411375	total: 8.14s	remaining: 4.58s
# 32:	learn: 1708.5859886	total: 8.43s	remaining: 4.34s
# 33:	learn: 1707.2432917	total: 8.64s	remaining: 4.07s
# 34:	learn: 1703.6812057	total: 8.93s	remaining: 3.83s
# 35:	learn: 1698.8768068	total: 9.14s	remaining: 3.55s
# 36:	learn: 1696.4683150	total: 9.43s	remaining: 3.31s
# 37:	learn: 1693.9514618	total: 9.63s	remaining: 3.04s
# 38:	learn: 1690.1578227	total: 9.85s	remaining: 2.78s
# 39:	learn: 1688.6578736	total: 10.1s	remaining: 2.53s
# 40:	learn: 1685.9829028	total: 10.4s	remaining: 2.29s
# 41:	learn: 1682.4547954	total: 10.6s	remaining: 2.02s
# 42:	learn: 1681.3449577	total: 10.9s	remaining: 1.78s
# 43:	learn: 1678.4479049	total: 11.1s	remaining: 1.52s
# 44:	learn: 1674.5082072	total: 11.4s	remaining: 1.27s
# 45:	learn: 1671.5716385	total: 11.6s	remaining: 1.01s
# 46:	learn: 1669.0668681	total: 11.9s	remaining: 761ms
# 47:	learn: 1667.9175455	total: 12.2s	remaining: 509ms
# 48:	learn: 1666.5968262	total: 12.4s	remaining: 254ms
# 49:	learn: 1664.8744814	total: 12.6s	remaining: 0us
# 0:	learn: 3199.7052087	total: 278ms	remaining: 13.6s
# 1:	learn: 2547.2253570	total: 578ms	remaining: 13.9s
# 2:	learn: 2230.9940544	total: 784ms	remaining: 12.3s
# 3:	learn: 2081.8861270	total: 1.08s	remaining: 12.4s
# 4:	learn: 2010.8836485	total: 1.29s	remaining: 11.6s
# 5:	learn: 1962.3569319	total: 1.57s	remaining: 11.6s
# 6:	learn: 1939.0959898	total: 1.87s	remaining: 11.5s
# 7:	learn: 1913.5664976	total: 2.08s	remaining: 10.9s
# 8:	learn: 1895.6787175	total: 2.37s	remaining: 10.8s
# 9:	learn: 1874.9573626	total: 2.58s	remaining: 10.3s
# 10:	learn: 1863.1647257	total: 2.87s	remaining: 10.2s
# 11:	learn: 1849.1914499	total: 3.08s	remaining: 9.74s
# 12:	learn: 1836.3476662	total: 3.37s	remaining: 9.59s
# 13:	learn: 1820.4549145	total: 3.58s	remaining: 9.19s
# 14:	learn: 1809.4744544	total: 3.87s	remaining: 9.03s
# 15:	learn: 1799.9085507	total: 4.08s	remaining: 8.66s
# 16:	learn: 1792.0700415	total: 4.37s	remaining: 8.47s
# 17:	learn: 1781.3186319	total: 4.57s	remaining: 8.13s
# 18:	learn: 1773.3089725	total: 4.87s	remaining: 7.94s
# 19:	learn: 1766.1361497	total: 5.16s	remaining: 7.74s
# 20:	learn: 1760.1002185	total: 5.37s	remaining: 7.41s
# 21:	learn: 1752.0617167	total: 5.66s	remaining: 7.2s
# 22:	learn: 1749.0820536	total: 5.86s	remaining: 6.88s
# 23:	learn: 1744.4366385	total: 6.16s	remaining: 6.67s
# 24:	learn: 1739.6050151	total: 6.36s	remaining: 6.36s
# 25:	learn: 1735.7407697	total: 6.65s	remaining: 6.14s
# 26:	learn: 1730.1123179	total: 6.86s	remaining: 5.84s
# 27:	learn: 1724.8236116	total: 7.06s	remaining: 5.55s
# 28:	learn: 1719.0525565	total: 7.35s	remaining: 5.32s
# 29:	learn: 1714.9402337	total: 7.57s	remaining: 5.04s
# 30:	learn: 1709.6009830	total: 7.85s	remaining: 4.81s
# 31:	learn: 1706.1721270	total: 8.06s	remaining: 4.54s
# 32:	learn: 1703.1730938	total: 8.35s	remaining: 4.3s
# 33:	learn: 1700.1287701	total: 8.65s	remaining: 4.07s
# 34:	learn: 1698.4429998	total: 8.85s	remaining: 3.79s
# 35:	learn: 1696.2407397	total: 9.14s	remaining: 3.56s
# 36:	learn: 1694.0747892	total: 9.35s	remaining: 3.29s
# 37:	learn: 1691.0383796	total: 9.64s	remaining: 3.04s
# 38:	learn: 1689.2692965	total: 9.85s	remaining: 2.78s
# 39:	learn: 1687.2109670	total: 10.1s	remaining: 2.51s
# 40:	learn: 1684.8144641	total: 10.3s	remaining: 2.27s
# 41:	learn: 1682.2570922	total: 10.6s	remaining: 2.03s
# 42:	learn: 1679.6273825	total: 10.8s	remaining: 1.76s
# 43:	learn: 1677.0685222	total: 11.1s	remaining: 1.52s
# 44:	learn: 1673.7183273	total: 11.3s	remaining: 1.26s
# 45:	learn: 1670.4116218	total: 11.6s	remaining: 1.01s
# 46:	learn: 1666.9052644	total: 11.8s	remaining: 756ms
# 47:	learn: 1665.8879083	total: 12.1s	remaining: 505ms
# 48:	learn: 1663.4847419	total: 12.3s	remaining: 252ms
# 49:	learn: 1661.6246811	total: 12.6s	remaining: 0us
# 0:	learn: 3219.6548705	total: 268ms	remaining: 13.1s
# 1:	learn: 2513.6955489	total: 568ms	remaining: 13.6s
# 2:	learn: 2217.3031867	total: 775ms	remaining: 12.1s
# 3:	learn: 2073.8954011	total: 1.07s	remaining: 12.4s
# 4:	learn: 1999.5993659	total: 1.37s	remaining: 12.3s
# 5:	learn: 1958.5429885	total: 1.57s	remaining: 11.5s
# 6:	learn: 1923.1747669	total: 1.86s	remaining: 11.5s
# 7:	learn: 1897.2350493	total: 2.07s	remaining: 10.9s
# 8:	learn: 1877.2859384	total: 2.36s	remaining: 10.8s
# 9:	learn: 1863.6980793	total: 2.57s	remaining: 10.3s
# 10:	learn: 1850.5047691	total: 2.86s	remaining: 10.1s
# 11:	learn: 1837.3193449	total: 3.07s	remaining: 9.71s
# 12:	learn: 1822.9312517	total: 3.36s	remaining: 9.55s
# 13:	learn: 1808.9025705	total: 3.56s	remaining: 9.17s
# 14:	learn: 1802.8448189	total: 3.86s	remaining: 9s
# 15:	learn: 1794.1421837	total: 4.06s	remaining: 8.63s
# 16:	learn: 1784.8725112	total: 4.36s	remaining: 8.46s
# 17:	learn: 1779.0068061	total: 4.56s	remaining: 8.11s
# 18:	learn: 1761.4498474	total: 4.85s	remaining: 7.92s
# 19:	learn: 1745.8717439	total: 5.06s	remaining: 7.59s
# 20:	learn: 1736.1150275	total: 5.26s	remaining: 7.26s
# 21:	learn: 1730.2212503	total: 5.55s	remaining: 7.07s
# 22:	learn: 1724.5401360	total: 5.76s	remaining: 6.76s
# 23:	learn: 1718.7223746	total: 6.05s	remaining: 6.56s
# 24:	learn: 1715.4323181	total: 6.35s	remaining: 6.35s
# 25:	learn: 1712.5689073	total: 6.55s	remaining: 6.05s
# 26:	learn: 1706.3129673	total: 6.76s	remaining: 5.75s
# 27:	learn: 1702.3909981	total: 7.05s	remaining: 5.54s
# 28:	learn: 1697.9834485	total: 7.34s	remaining: 5.32s
# 29:	learn: 1695.2543463	total: 7.55s	remaining: 5.03s
# 30:	learn: 1688.9154604	total: 7.84s	remaining: 4.81s
# 31:	learn: 1686.1523455	total: 8.05s	remaining: 4.53s
# 32:	learn: 1681.5044704	total: 8.25s	remaining: 4.25s
# 33:	learn: 1677.9334236	total: 8.55s	remaining: 4.02s
# 34:	learn: 1675.0298179	total: 8.75s	remaining: 3.75s
# 35:	learn: 1672.2531923	total: 9.04s	remaining: 3.52s
# 36:	learn: 1669.2487631	total: 9.25s	remaining: 3.25s
# 37:	learn: 1667.0570941	total: 9.54s	remaining: 3.01s
# 38:	learn: 1664.9928087	total: 9.74s	remaining: 2.75s
# 39:	learn: 1661.8624742	total: 10s	remaining: 2.51s
# 40:	learn: 1660.2308401	total: 10.2s	remaining: 2.25s
# 41:	learn: 1657.6479310	total: 10.5s	remaining: 2.01s
# 42:	learn: 1655.2918945	total: 10.7s	remaining: 1.75s
# 43:	learn: 1653.5182880	total: 11s	remaining: 1.5s
# 44:	learn: 1651.2815538	total: 11.2s	remaining: 1.25s
# 45:	learn: 1649.2487409	total: 11.5s	remaining: 1s
# 46:	learn: 1647.9275311	total: 11.7s	remaining: 749ms
# 47:	learn: 1646.1350026	total: 11.9s	remaining: 497ms
# 48:	learn: 1644.6597028	total: 12.2s	remaining: 250ms
# 49:	learn: 1641.7808906	total: 12.4s	remaining: 0us
# 0:	learn: 4368.9969582	total: 211ms	remaining: 10.3s
# 1:	learn: 4084.8909166	total: 506ms	remaining: 12.2s
# 2:	learn: 3827.9102976	total: 804ms	remaining: 12.6s
# 3:	learn: 3603.9405760	total: 1.01s	remaining: 11.7s
# 4:	learn: 3400.9355183	total: 1.3s	remaining: 11.7s
# 5:	learn: 3224.6648767	total: 1.6s	remaining: 11.7s
# 6:	learn: 3064.2828081	total: 1.81s	remaining: 11.1s
# 7:	learn: 2930.6676293	total: 2.1s	remaining: 11s
# 8:	learn: 2808.4631892	total: 2.4s	remaining: 10.9s
# 9:	learn: 2701.7609495	total: 2.6s	remaining: 10.4s
# 10:	learn: 2606.8535072	total: 2.9s	remaining: 10.3s
# 11:	learn: 2523.3045257	total: 3.1s	remaining: 9.82s
# 12:	learn: 2448.9847958	total: 3.39s	remaining: 9.66s
# 13:	learn: 2382.6788950	total: 3.6s	remaining: 9.26s
# 14:	learn: 2324.6957798	total: 3.9s	remaining: 9.09s
# 15:	learn: 2273.2207132	total: 4.19s	remaining: 8.9s
# 16:	learn: 2230.0352105	total: 4.39s	remaining: 8.53s
# 17:	learn: 2192.5978150	total: 4.69s	remaining: 8.34s
# 18:	learn: 2158.7524983	total: 4.89s	remaining: 7.99s
# 19:	learn: 2127.4816263	total: 5.19s	remaining: 7.78s
# 20:	learn: 2099.2563969	total: 5.39s	remaining: 7.44s
# 21:	learn: 2076.5687933	total: 5.68s	remaining: 7.23s
# 22:	learn: 2051.8870450	total: 5.89s	remaining: 6.91s
# 23:	learn: 2030.3050520	total: 6.18s	remaining: 6.7s
# 24:	learn: 2013.8076967	total: 6.39s	remaining: 6.39s
# 25:	learn: 1998.1254275	total: 6.68s	remaining: 6.17s
# 26:	learn: 1984.7692546	total: 6.97s	remaining: 5.94s
# 27:	learn: 1973.6361064	total: 7.18s	remaining: 5.64s
# 28:	learn: 1961.7355886	total: 7.47s	remaining: 5.41s
# 29:	learn: 1950.1877033	total: 7.68s	remaining: 5.12s
# 30:	learn: 1940.8433312	total: 7.97s	remaining: 4.89s
# 31:	learn: 1931.6201704	total: 8.18s	remaining: 4.6s
# 32:	learn: 1924.0114751	total: 8.47s	remaining: 4.36s
# 33:	learn: 1916.7000956	total: 8.68s	remaining: 4.08s
# 34:	learn: 1909.4633177	total: 8.97s	remaining: 3.84s
# 35:	learn: 1902.9374954	total: 9.17s	remaining: 3.57s
# 36:	learn: 1895.3693871	total: 9.38s	remaining: 3.29s
# 37:	learn: 1887.1113119	total: 9.67s	remaining: 3.05s
# 38:	learn: 1879.4941487	total: 9.87s	remaining: 2.79s
# 39:	learn: 1874.4476788	total: 10.2s	remaining: 2.54s
# 40:	learn: 1868.7733688	total: 10.4s	remaining: 2.28s
# 41:	learn: 1862.5902285	total: 10.7s	remaining: 2.03s
# 42:	learn: 1858.9063733	total: 10.9s	remaining: 1.77s
# 43:	learn: 1854.9163184	total: 11.2s	remaining: 1.52s
# 44:	learn: 1849.7444984	total: 11.4s	remaining: 1.26s
# 45:	learn: 1843.3021322	total: 11.7s	remaining: 1.01s
# 46:	learn: 1839.3317019	total: 11.9s	remaining: 757ms
# 47:	learn: 1836.1136355	total: 12.2s	remaining: 507ms
# 48:	learn: 1833.7857567	total: 12.4s	remaining: 252ms
# 49:	learn: 1829.8853944	total: 12.7s	remaining: 0us
# 0:	learn: 4358.1145490	total: 218ms	remaining: 10.7s
# 1:	learn: 4074.1563457	total: 517ms	remaining: 12.4s
# 2:	learn: 3823.2246504	total: 816ms	remaining: 12.8s
# 3:	learn: 3598.9904089	total: 1.02s	remaining: 11.8s
# 4:	learn: 3404.1386185	total: 1.32s	remaining: 11.9s
# 5:	learn: 3227.3668499	total: 1.53s	remaining: 11.2s
# 6:	learn: 3075.6726815	total: 1.82s	remaining: 11.2s
# 7:	learn: 2936.1653086	total: 2.11s	remaining: 11.1s
# 8:	learn: 2814.8614428	total: 2.33s	remaining: 10.6s
# 9:	learn: 2707.9686891	total: 2.61s	remaining: 10.5s
# 10:	learn: 2616.2442690	total: 2.82s	remaining: 9.99s
# 11:	learn: 2532.4796959	total: 3.11s	remaining: 9.86s
# 12:	learn: 2459.0362486	total: 3.32s	remaining: 9.45s
# 13:	learn: 2394.4378940	total: 3.6s	remaining: 9.27s
# 14:	learn: 2337.8315956	total: 3.9s	remaining: 9.11s
# 15:	learn: 2286.6509578	total: 4.11s	remaining: 8.73s
# 16:	learn: 2243.1588122	total: 4.4s	remaining: 8.54s
# 17:	learn: 2201.7859758	total: 4.61s	remaining: 8.2s
# 18:	learn: 2166.4036196	total: 4.9s	remaining: 8s
# 19:	learn: 2133.7824387	total: 5.2s	remaining: 7.79s
# 20:	learn: 2107.4865387	total: 5.4s	remaining: 7.46s
# 21:	learn: 2081.9271215	total: 5.69s	remaining: 7.25s
# 22:	learn: 2060.0129905	total: 5.9s	remaining: 6.93s
# 23:	learn: 2039.5433313	total: 6.19s	remaining: 6.71s
# 24:	learn: 2021.5708050	total: 6.4s	remaining: 6.4s
# 25:	learn: 2006.4368633	total: 6.69s	remaining: 6.18s
# 26:	learn: 1992.7402224	total: 6.9s	remaining: 5.88s
# 27:	learn: 1980.8305813	total: 7.19s	remaining: 5.65s
# 28:	learn: 1968.7134111	total: 7.4s	remaining: 5.36s
# 29:	learn: 1957.3466773	total: 7.69s	remaining: 5.13s
# 30:	learn: 1945.5300474	total: 7.98s	remaining: 4.89s
# 31:	learn: 1935.8610997	total: 8.19s	remaining: 4.61s
# 32:	learn: 1926.5553816	total: 8.39s	remaining: 4.33s
# 33:	learn: 1918.8566269	total: 8.69s	remaining: 4.09s
# 34:	learn: 1912.2824438	total: 8.89s	remaining: 3.81s
# 35:	learn: 1905.0284423	total: 9.19s	remaining: 3.57s
# 36:	learn: 1897.0438196	total: 9.48s	remaining: 3.33s
# 37:	learn: 1890.0616540	total: 9.69s	remaining: 3.06s
# 38:	learn: 1884.0784359	total: 9.89s	remaining: 2.79s
# 39:	learn: 1877.2429260	total: 10.2s	remaining: 2.54s
# 40:	learn: 1871.3592952	total: 10.4s	remaining: 2.28s
# 41:	learn: 1866.7392784	total: 10.7s	remaining: 2.03s
# 42:	learn: 1862.4902918	total: 10.9s	remaining: 1.77s
# 43:	learn: 1858.5611652	total: 11.2s	remaining: 1.52s
# 44:	learn: 1855.1534700	total: 11.4s	remaining: 1.26s
# 45:	learn: 1851.1457131	total: 11.7s	remaining: 1.01s
# 46:	learn: 1847.5341303	total: 11.9s	remaining: 758ms
# 47:	learn: 1844.5951284	total: 12.2s	remaining: 507ms
# 48:	learn: 1840.4371381	total: 12.4s	remaining: 253ms
# 49:	learn: 1836.4987064	total: 12.7s	remaining: 0us
# 0:	learn: 4363.7875439	total: 260ms	remaining: 12.8s
# 1:	learn: 4073.8263755	total: 560ms	remaining: 13.4s
# 2:	learn: 3817.9308621	total: 769ms	remaining: 12s
# 3:	learn: 3595.2537941	total: 1.06s	remaining: 12.2s
# 4:	learn: 3397.2657431	total: 1.32s	remaining: 11.9s
# 5:	learn: 3222.7646635	total: 1.56s	remaining: 11.5s
# 6:	learn: 3066.7630955	total: 1.85s	remaining: 11.4s
# 7:	learn: 2930.7491084	total: 2.06s	remaining: 10.8s
# 8:	learn: 2805.0571156	total: 2.27s	remaining: 10.3s
# 9:	learn: 2697.5809944	total: 2.56s	remaining: 10.2s
# 10:	learn: 2600.4414570	total: 2.85s	remaining: 10.1s
# 11:	learn: 2516.9751449	total: 3.06s	remaining: 9.7s
# 12:	learn: 2441.9081709	total: 3.35s	remaining: 9.55s
# 13:	learn: 2377.4529103	total: 3.56s	remaining: 9.15s
# 14:	learn: 2320.6676427	total: 3.85s	remaining: 8.99s
# 15:	learn: 2269.2371556	total: 4.06s	remaining: 8.63s
# 16:	learn: 2224.6305768	total: 4.35s	remaining: 8.45s
# 17:	learn: 2186.1173172	total: 4.56s	remaining: 8.1s
# 18:	learn: 2150.4749137	total: 4.85s	remaining: 7.91s
# 19:	learn: 2120.8706624	total: 5.06s	remaining: 7.58s
# 20:	learn: 2093.4098168	total: 5.35s	remaining: 7.38s
# 21:	learn: 2067.4449877	total: 5.55s	remaining: 7.07s
# 22:	learn: 2044.8483110	total: 5.84s	remaining: 6.86s
# 23:	learn: 2024.7971079	total: 6.05s	remaining: 6.55s
# 24:	learn: 2008.5162805	total: 6.34s	remaining: 6.34s
# 25:	learn: 1992.8099137	total: 6.55s	remaining: 6.05s
# 26:	learn: 1979.1211870	total: 6.84s	remaining: 5.83s
# 27:	learn: 1965.8686100	total: 7.05s	remaining: 5.54s
# 28:	learn: 1953.9838753	total: 7.34s	remaining: 5.32s
# 29:	learn: 1940.6733228	total: 7.55s	remaining: 5.03s
# 30:	learn: 1931.3274279	total: 7.84s	remaining: 4.8s
# 31:	learn: 1917.8160748	total: 8.05s	remaining: 4.53s
# 32:	learn: 1911.2901996	total: 8.34s	remaining: 4.29s
# 33:	learn: 1902.9531353	total: 8.54s	remaining: 4.02s
# 34:	learn: 1895.8748978	total: 8.84s	remaining: 3.79s
# 35:	learn: 1887.9343161	total: 9.04s	remaining: 3.52s
# 36:	learn: 1880.1088140	total: 9.34s	remaining: 3.28s
# 37:	learn: 1872.9851375	total: 9.54s	remaining: 3.01s
# 38:	learn: 1865.8792147	total: 9.83s	remaining: 2.77s
# 39:	learn: 1860.2807925	total: 10s	remaining: 2.51s
# 40:	learn: 1855.4231610	total: 10.3s	remaining: 2.27s
# 41:	learn: 1848.8490334	total: 10.6s	remaining: 2.02s
# 42:	learn: 1843.3896283	total: 10.8s	remaining: 1.76s
# 43:	learn: 1839.8656315	total: 11s	remaining: 1.5s
# 44:	learn: 1835.9271569	total: 11.3s	remaining: 1.26s
# 45:	learn: 1831.8058504	total: 11.6s	remaining: 1.01s
# 46:	learn: 1828.3833185	total: 11.8s	remaining: 755ms
# 47:	learn: 1824.1988596	total: 12.1s	remaining: 505ms
# 48:	learn: 1821.0694561	total: 12.3s	remaining: 252ms
# 49:	learn: 1817.7390513	total: 12.6s	remaining: 0us
# 0:	learn: 3132.9871219	total: 379ms	remaining: 3.41s
# 1:	learn: 2412.5882084	total: 687ms	remaining: 2.75s
# 2:	learn: 2111.9906532	total: 1.08s	remaining: 2.52s
# 3:	learn: 1977.8293446	total: 1.47s	remaining: 2.21s
# 4:	learn: 1910.8133359	total: 1.78s	remaining: 1.78s
# 5:	learn: 1875.4238509	total: 2.08s	remaining: 1.39s
# 6:	learn: 1846.2021489	total: 2.38s	remaining: 1.02s
# 7:	learn: 1824.2548953	total: 2.77s	remaining: 693ms
# 8:	learn: 1801.8479718	total: 3.07s	remaining: 341ms
# 9:	learn: 1783.4196896	total: 3.38s	remaining: 0us
# 0:	learn: 3098.2188986	total: 380ms	remaining: 3.42s
# 1:	learn: 2404.0888279	total: 686ms	remaining: 2.75s
# 2:	learn: 2106.2555109	total: 1.08s	remaining: 2.52s
# 3:	learn: 1960.2213831	total: 1.38s	remaining: 2.07s
# 4:	learn: 1891.9737544	total: 1.68s	remaining: 1.68s
# 5:	learn: 1857.9647768	total: 1.99s	remaining: 1.32s
# 6:	learn: 1826.7406338	total: 2.38s	remaining: 1.02s
# 7:	learn: 1812.0186204	total: 2.68s	remaining: 670ms
# 8:	learn: 1794.9090232	total: 2.98s	remaining: 331ms
# 9:	learn: 1776.5174971	total: 3.37s	remaining: 0us
# 0:	learn: 3106.3451462	total: 369ms	remaining: 3.32s
# 1:	learn: 2400.7352281	total: 675ms	remaining: 2.7s
# 2:	learn: 2098.8523010	total: 983ms	remaining: 2.29s
# 3:	learn: 1975.0775998	total: 1.37s	remaining: 2.05s
# 4:	learn: 1905.3814996	total: 1.67s	remaining: 1.67s
# 5:	learn: 1862.1628719	total: 1.97s	remaining: 1.31s
# 6:	learn: 1828.9397752	total: 2.36s	remaining: 1.01s
# 7:	learn: 1805.5250158	total: 2.67s	remaining: 667ms
# 8:	learn: 1792.2393234	total: 2.97s	remaining: 330ms
# 9:	learn: 1772.2808409	total: 3.28s	remaining: 0us
# 0:	learn: 4348.4202735	total: 323ms	remaining: 2.9s
# 1:	learn: 4042.7406537	total: 631ms	remaining: 2.52s
# 2:	learn: 3772.4492786	total: 1.02s	remaining: 2.39s
# 3:	learn: 3537.0279609	total: 1.32s	remaining: 1.99s
# 4:	learn: 3325.5247701	total: 1.63s	remaining: 1.63s
# 5:	learn: 3139.5589992	total: 1.93s	remaining: 1.29s
# 6:	learn: 2973.2493072	total: 2.23s	remaining: 957ms
# 7:	learn: 2826.1155091	total: 2.62s	remaining: 654ms
# 8:	learn: 2698.1749086	total: 2.92s	remaining: 324ms
# 9:	learn: 2589.9423575	total: 3.22s	remaining: 0us
# 0:	learn: 4339.5938327	total: 398ms	remaining: 3.58s
# 1:	learn: 4037.6148224	total: 794ms	remaining: 3.17s
# 2:	learn: 3769.4542453	total: 1.09s	remaining: 2.56s
# 3:	learn: 3534.6864135	total: 1.4s	remaining: 2.1s
# 4:	learn: 3330.6067755	total: 1.71s	remaining: 1.71s
# 5:	learn: 3141.6821739	total: 2.09s	remaining: 1.39s
# 6:	learn: 2979.9526684	total: 2.39s	remaining: 1.03s
# 7:	learn: 2836.6709558	total: 2.7s	remaining: 675ms
# 8:	learn: 2709.9963912	total: 3.09s	remaining: 343ms
# 9:	learn: 2599.9823761	total: 3.39s	remaining: 0us
# 0:	learn: 4343.0470219	total: 298ms	remaining: 2.68s
# 1:	learn: 4038.5529395	total: 688ms	remaining: 2.75s
# 2:	learn: 3769.4314952	total: 1.08s	remaining: 2.52s
# 3:	learn: 3529.8205136	total: 1.38s	remaining: 2.07s
# 4:	learn: 3318.3242493	total: 1.68s	remaining: 1.68s
# 5:	learn: 3128.1419586	total: 1.99s	remaining: 1.32s
# 6:	learn: 2968.1138339	total: 2.29s	remaining: 983ms
# 7:	learn: 2828.6566203	total: 2.68s	remaining: 669ms
# 8:	learn: 2702.2360062	total: 2.98s	remaining: 331ms
# 9:	learn: 2591.4806572	total: 3.28s	remaining: 0us
# 0:	learn: 3134.9819065	total: 274ms	remaining: 2.47s
# 1:	learn: 2414.5933118	total: 666ms	remaining: 2.66s
# 2:	learn: 2113.9700228	total: 975ms	remaining: 2.27s
# 3:	learn: 1979.8771683	total: 1.36s	remaining: 2.04s
# 4:	learn: 1912.9576297	total: 1.66s	remaining: 1.66s
# 5:	learn: 1877.9593516	total: 1.96s	remaining: 1.31s
# 6:	learn: 1848.9347971	total: 2.26s	remaining: 970ms
# 7:	learn: 1827.1670446	total: 2.56s	remaining: 641ms
# 8:	learn: 1809.7214270	total: 2.95s	remaining: 328ms
# 9:	learn: 1795.4825705	total: 3.25s	remaining: 0us
# 0:	learn: 3100.9129855	total: 366ms	remaining: 3.3s
# 1:	learn: 2406.0848612	total: 673ms	remaining: 2.69s
# 2:	learn: 2109.3237583	total: 1.06s	remaining: 2.48s
# 3:	learn: 1963.4627456	total: 1.36s	remaining: 2.05s
# 4:	learn: 1894.9497214	total: 1.67s	remaining: 1.67s
# 5:	learn: 1861.3064970	total: 2.06s	remaining: 1.37s
# 6:	learn: 1829.9713736	total: 2.36s	remaining: 1.01s
# 7:	learn: 1809.2859203	total: 2.66s	remaining: 666ms
# 8:	learn: 1795.1348742	total: 2.97s	remaining: 330ms
# 9:	learn: 1768.4724807	total: 3.36s	remaining: 0us
# 0:	learn: 3109.6840028	total: 264ms	remaining: 2.38s
# 1:	learn: 2404.3053692	total: 658ms	remaining: 2.63s
# 2:	learn: 2101.3336817	total: 1.05s	remaining: 2.45s
# 3:	learn: 1977.0233090	total: 1.35s	remaining: 2.03s
# 4:	learn: 1907.1790407	total: 1.65s	remaining: 1.65s
# 5:	learn: 1864.0108174	total: 1.96s	remaining: 1.3s
# 6:	learn: 1827.4244442	total: 2.35s	remaining: 1.01s
# 7:	learn: 1807.6304142	total: 2.65s	remaining: 663ms
# 8:	learn: 1794.6344672	total: 2.95s	remaining: 328ms
# 9:	learn: 1771.6037504	total: 3.25s	remaining: 0us
# 0:	learn: 4348.9331039	total: 358ms	remaining: 3.22s
# 1:	learn: 4043.7773679	total: 665ms	remaining: 2.66s
# 2:	learn: 3774.1034794	total: 1.06s	remaining: 2.47s
# 3:	learn: 3538.4319743	total: 1.36s	remaining: 2.04s
# 4:	learn: 3332.1539102	total: 1.66s	remaining: 1.66s
# 5:	learn: 3143.0197599	total: 1.96s	remaining: 1.3s
# 6:	learn: 2980.6752424	total: 2.26s	remaining: 969ms
# 7:	learn: 2836.7375475	total: 2.65s	remaining: 663ms
# 8:	learn: 2709.4288093	total: 2.96s	remaining: 328ms
# 9:	learn: 2598.7285814	total: 3.26s	remaining: 0us
# 0:	learn: 4340.2574614	total: 353ms	remaining: 3.18s
# 1:	learn: 4039.2501285	total: 659ms	remaining: 2.63s
# 2:	learn: 3771.4089324	total: 959ms	remaining: 2.24s
# 3:	learn: 3536.8951360	total: 1.35s	remaining: 2.03s
# 4:	learn: 3333.0320672	total: 1.65s	remaining: 1.65s
# 5:	learn: 3144.3173833	total: 1.96s	remaining: 1.3s
# 6:	learn: 2984.4552827	total: 2.26s	remaining: 967ms
# 7:	learn: 2837.4583695	total: 2.65s	remaining: 662ms
# 8:	learn: 2713.8951329	total: 2.96s	remaining: 329ms
# 9:	learn: 2600.7904596	total: 3.25s	remaining: 0us
# 0:	learn: 4343.8910615	total: 353ms	remaining: 3.18s
# 1:	learn: 4039.9607904	total: 659ms	remaining: 2.64s
# 2:	learn: 3771.1335175	total: 1.05s	remaining: 2.45s
# 3:	learn: 3531.8847370	total: 1.35s	remaining: 2.03s
# 4:	learn: 3322.6244760	total: 1.65s	remaining: 1.65s
# 5:	learn: 3140.1246198	total: 1.96s	remaining: 1.3s
# 6:	learn: 2973.2966622	total: 2.35s	remaining: 1.01s
# 7:	learn: 2829.6583570	total: 2.65s	remaining: 663ms
# 8:	learn: 2700.8372230	total: 2.95s	remaining: 328ms
# 9:	learn: 2589.3616757	total: 3.35s	remaining: 0us
# 0:	learn: 3132.9871219	total: 395ms	remaining: 19.3s
# 1:	learn: 2412.5882084	total: 700ms	remaining: 16.8s
# 2:	learn: 2111.9906532	total: 1.09s	remaining: 17.1s
# 3:	learn: 1977.8293446	total: 1.4s	remaining: 16.1s
# 4:	learn: 1910.8133359	total: 1.7s	remaining: 15.3s
# 5:	learn: 1875.4238509	total: 2s	remaining: 14.7s
# 6:	learn: 1846.2021489	total: 2.39s	remaining: 14.7s
# 7:	learn: 1824.2548953	total: 2.69s	remaining: 14.1s
# 8:	learn: 1801.8479718	total: 2.99s	remaining: 13.6s
# 9:	learn: 1783.4196896	total: 3.29s	remaining: 13.2s
# 10:	learn: 1755.2070463	total: 3.6s	remaining: 12.7s
# 11:	learn: 1745.0799472	total: 3.99s	remaining: 12.6s
# 12:	learn: 1729.3817566	total: 4.29s	remaining: 12.2s
# 13:	learn: 1722.4638970	total: 4.59s	remaining: 11.8s
# 14:	learn: 1715.8832928	total: 4.89s	remaining: 11.4s
# 15:	learn: 1710.0621530	total: 5.28s	remaining: 11.2s
# 16:	learn: 1699.9599416	total: 5.58s	remaining: 10.8s
# 17:	learn: 1694.0990525	total: 5.88s	remaining: 10.5s
# 18:	learn: 1688.0837538	total: 6.18s	remaining: 10.1s
# 19:	learn: 1683.2316182	total: 6.58s	remaining: 9.86s
# 20:	learn: 1678.1019258	total: 6.88s	remaining: 9.5s
# 21:	learn: 1671.9826164	total: 7.18s	remaining: 9.13s
# 22:	learn: 1664.6721534	total: 7.48s	remaining: 8.78s
# 23:	learn: 1658.5091981	total: 7.87s	remaining: 8.53s
# 24:	learn: 1653.7208509	total: 8.17s	remaining: 8.17s
# 25:	learn: 1650.3101115	total: 8.47s	remaining: 7.82s
# 26:	learn: 1646.2341895	total: 8.77s	remaining: 7.47s
# 27:	learn: 1640.7542567	total: 9.08s	remaining: 7.13s
# 28:	learn: 1636.4356504	total: 9.38s	remaining: 6.79s
# 29:	learn: 1631.9806707	total: 9.77s	remaining: 6.51s
# 30:	learn: 1626.6724754	total: 10.1s	remaining: 6.17s
# 31:	learn: 1623.2957336	total: 10.4s	remaining: 5.84s
# 32:	learn: 1619.9138616	total: 10.8s	remaining: 5.54s
# 33:	learn: 1618.1041831	total: 11.1s	remaining: 5.21s
# 34:	learn: 1615.7648496	total: 11.4s	remaining: 4.87s
# 35:	learn: 1610.2378973	total: 11.7s	remaining: 4.54s
# 36:	learn: 1603.6652203	total: 12.1s	remaining: 4.24s
# 37:	learn: 1600.5236474	total: 12.4s	remaining: 3.9s
# 38:	learn: 1599.2902759	total: 12.7s	remaining: 3.57s
# 39:	learn: 1595.8519614	total: 13s	remaining: 3.24s
# 40:	learn: 1593.0863944	total: 13.4s	remaining: 2.93s
# 41:	learn: 1590.7738362	total: 13.7s	remaining: 2.6s
# 42:	learn: 1585.3168141	total: 14s	remaining: 2.27s
# 43:	learn: 1583.1620233	total: 14.4s	remaining: 1.96s
# 44:	learn: 1581.1144653	total: 14.7s	remaining: 1.63s
# 45:	learn: 1577.8736058	total: 15.1s	remaining: 1.31s
# 46:	learn: 1576.4468402	total: 15.4s	remaining: 980ms
# 47:	learn: 1573.1569501	total: 15.8s	remaining: 656ms
# 48:	learn: 1572.3462643	total: 16.1s	remaining: 328ms
# 49:	learn: 1570.4478111	total: 16.4s	remaining: 0us
# 0:	learn: 3098.2188986	total: 362ms	remaining: 17.7s
# 1:	learn: 2404.0888279	total: 670ms	remaining: 16.1s
# 2:	learn: 2106.2555109	total: 1.06s	remaining: 16.7s
# 3:	learn: 1960.2213831	total: 1.36s	remaining: 15.7s
# 4:	learn: 1891.9737544	total: 1.67s	remaining: 15s
# 5:	learn: 1857.9647768	total: 1.96s	remaining: 14.4s
# 6:	learn: 1826.7406338	total: 2.27s	remaining: 13.9s
# 7:	learn: 1812.0186204	total: 2.66s	remaining: 14s
# 8:	learn: 1794.9090232	total: 2.96s	remaining: 13.5s
# 9:	learn: 1776.5174971	total: 3.26s	remaining: 13s
# ...
# 1:	learn: 2340.0825694	total: 758ms	remaining: 18.2s
# 2:	learn: 2031.1960449	total: 1.25s	remaining: 19.6s
# 3:	learn: 1907.4890820	total: 1.65s	remaining: 18.9s
# 4:	learn: 1827.9178805	total: 1.96s	remaining: 17.6s
# 5:	learn: 1790.8081661	total: 2.35s	remaining: 17.3s
# 6:	learn: 1762.7644032	total: 2.84s	remaining: 17.5s
# 7:	learn: 1738.0192813	total: 3.16s	remaining: 16.6s
# 8:	learn: 1723.7152685	total: 3.56s	remaining: 16.2s
# 9:	learn: 1711.9925318	total: 4.04s	remaining: 16.2s
# 10:	learn: 1696.8873498	total: 4.35s	remaining: 15.4s
# 11:	learn: 1687.9831009	total: 4.84s	remaining: 15.3s
# 12:	learn: 1676.6874794	total: 5.15s	remaining: 14.7s
# 13:	learn: 1666.4208032	total: 5.55s	remaining: 14.3s
# 14:	learn: 1660.3162456	total: 5.95s	remaining: 13.9s
# 15:	learn: 1650.9918000	total: 6.44s	remaining: 13.7s
# 16:	learn: 1643.5531858	total: 6.75s	remaining: 13.1s
# 17:	learn: 1632.7591883	total: 7.15s	remaining: 12.7s
# 18:	learn: 1626.3522910	total: 7.54s	remaining: 12.3s
# 19:	learn: 1621.1414905	total: 7.94s	remaining: 11.9s
# 20:	learn: 1615.8451745	total: 8.34s	remaining: 11.5s
# 21:	learn: 1609.1934724	total: 8.74s	remaining: 11.1s
# 22:	learn: 1600.5476689	total: 9.13s	remaining: 10.7s
# 23:	learn: 1591.8572024	total: 9.53s	remaining: 10.3s
# 24:	learn: 1581.7690901	total: 9.93s	remaining: 9.93s
# 25:	learn: 1576.5821444	total: 10.3s	remaining: 9.53s
# 26:	learn: 1569.3400626	total: 10.7s	remaining: 9.14s
# 27:	learn: 1562.6746160	total: 11.1s	remaining: 8.74s
# 28:	learn: 1557.3197165	total: 11.5s	remaining: 8.35s
# 29:	learn: 1553.8690109	total: 11.9s	remaining: 7.95s
# 30:	learn: 1549.3985119	total: 12.3s	remaining: 7.55s
# 31:	learn: 1546.0470360	total: 12.7s	remaining: 7.15s
# 32:	learn: 1543.1262628	total: 13s	remaining: 6.71s
# 33:	learn: 1542.5617382	total: 13.4s	remaining: 6.32s
# 34:	learn: 1540.7336845	total: 13.8s	remaining: 5.92s
# 35:	learn: 1537.8873474	total: 14.2s	remaining: 5.53s
# 36:	learn: 1534.3179952	total: 14.6s	remaining: 5.14s
# 37:	learn: 1528.5777736	total: 15s	remaining: 4.74s
# 38:	learn: 1526.6863686	total: 15.3s	remaining: 4.32s
# 39:	learn: 1524.2339457	total: 15.7s	remaining: 3.93s
# 40:	learn: 1520.4213385	total: 16.1s	remaining: 3.54s
# 41:	learn: 1514.9609078	total: 16.5s	remaining: 3.15s
# 42:	learn: 1511.3065605	total: 16.9s	remaining: 2.75s
# 43:	learn: 1505.7973410	total: 17.3s	remaining: 2.36s
# 44:	learn: 1502.7276029	total: 17.7s	remaining: 1.97s
# 45:	learn: 1497.1474448	total: 18.1s	remaining: 1.57s
# 46:	learn: 1492.9607669	total: 18.5s	remaining: 1.18s
# 47:	learn: 1490.7807588	total: 18.9s	remaining: 788ms
# 48:	learn: 1487.4625132	total: 19.3s	remaining: 394ms
# 49:	learn: 1485.9936988	total: 19.7s	remaining: 0us
# 0:	learn: 3052.3570399	total: 364ms	remaining: 17.8s
# 1:	learn: 2321.9804915	total: 765ms	remaining: 18.4s
# 2:	learn: 2026.0935418	total: 1.17s	remaining: 18.3s
# 3:	learn: 1902.2517865	total: 1.66s	remaining: 19s
# 4:	learn: 1829.0846320	total: 2.06s	remaining: 18.5s
# 5:	learn: 1794.8056826	total: 2.46s	remaining: 18s
# 6:	learn: 1756.9662317	total: 2.86s	remaining: 17.6s
# 7:	learn: 1742.5117206	total: 3.26s	remaining: 17.1s
# 8:	learn: 1722.1131965	total: 3.66s	remaining: 16.7s
# 9:	learn: 1703.7991148	total: 4.06s	remaining: 16.2s
# 10:	learn: 1687.3930276	total: 4.45s	remaining: 15.8s
# 11:	learn: 1667.6933197	total: 4.86s	remaining: 15.4s
# 12:	learn: 1652.3068283	total: 5.34s	remaining: 15.2s
# 13:	learn: 1643.3510835	total: 5.75s	remaining: 14.8s
# 14:	learn: 1633.2956743	total: 6.15s	remaining: 14.3s
# 15:	learn: 1622.5523082	total: 6.55s	remaining: 13.9s
# 16:	learn: 1617.0015917	total: 6.95s	remaining: 13.5s
# 17:	learn: 1605.8358012	total: 7.34s	remaining: 13.1s
# 18:	learn: 1595.9417461	total: 7.66s	remaining: 12.5s
# 19:	learn: 1589.3218134	total: 8.05s	remaining: 12.1s
# 20:	learn: 1582.0321024	total: 8.45s	remaining: 11.7s
# 21:	learn: 1577.9461058	total: 8.85s	remaining: 11.3s
# 22:	learn: 1569.4631108	total: 9.24s	remaining: 10.9s
# 23:	learn: 1564.6405734	total: 9.64s	remaining: 10.4s
# 24:	learn: 1557.0594977	total: 10s	remaining: 10s
# 25:	learn: 1550.8740838	total: 10.4s	remaining: 9.64s
# 26:	learn: 1544.0458226	total: 10.8s	remaining: 9.23s
# 27:	learn: 1540.6089020	total: 11.1s	remaining: 8.76s
# 28:	learn: 1536.6017263	total: 11.5s	remaining: 8.36s
# 29:	learn: 1533.5239188	total: 11.9s	remaining: 7.96s
# 30:	learn: 1529.5839427	total: 12.3s	remaining: 7.56s
# 31:	learn: 1523.7144597	total: 12.7s	remaining: 7.16s
# 32:	learn: 1520.0196850	total: 13.1s	remaining: 6.76s
# 33:	learn: 1515.6643854	total: 13.5s	remaining: 6.37s
# 34:	learn: 1511.0094906	total: 13.9s	remaining: 5.97s
# 35:	learn: 1505.7314611	total: 14.3s	remaining: 5.57s
# 36:	learn: 1501.6825804	total: 14.7s	remaining: 5.17s
# 37:	learn: 1499.0175449	total: 15.1s	remaining: 4.78s
# 38:	learn: 1496.5908807	total: 15.5s	remaining: 4.38s
# 39:	learn: 1493.8809892	total: 15.8s	remaining: 3.96s
# 40:	learn: 1491.4128172	total: 16.2s	remaining: 3.56s
# 41:	learn: 1487.1082843	total: 16.6s	remaining: 3.17s
# 42:	learn: 1484.3911853	total: 17s	remaining: 2.77s
# 43:	learn: 1480.7328501	total: 17.4s	remaining: 2.38s
# 44:	learn: 1479.6679462	total: 17.8s	remaining: 1.98s
# 45:	learn: 1478.2115051	total: 18.2s	remaining: 1.58s
# 46:	learn: 1474.1133024	total: 18.6s	remaining: 1.19s
# 47:	learn: 1471.5863406	total: 19s	remaining: 792ms
# 48:	learn: 1465.0096906	total: 19.4s	remaining: 396ms
# 49:	learn: 1463.0302088	total: 19.8s	remaining: 0us
# 0:	learn: 4333.0453301	total: 329ms	remaining: 16.1s
# 1:	learn: 4019.3858378	total: 732ms	remaining: 17.6s
# 2:	learn: 3740.9046090	total: 1.13s	remaining: 17.7s
# 3:	learn: 3495.5241378	total: 1.52s	remaining: 17.5s
# 4:	learn: 3280.8072506	total: 1.92s	remaining: 17.3s
# 5:	learn: 3088.6044634	total: 2.32s	remaining: 17s
# 6:	learn: 2921.2171258	total: 2.72s	remaining: 16.7s
# 7:	learn: 2771.2330095	total: 3.12s	remaining: 16.4s
# 8:	learn: 2645.1890140	total: 3.52s	remaining: 16s
# 9:	learn: 2532.4290004	total: 3.92s	remaining: 15.7s
# 10:	learn: 2432.8180410	total: 4.31s	remaining: 15.3s
# 11:	learn: 2345.4555024	total: 4.62s	remaining: 14.6s
# 12:	learn: 2266.4967079	total: 5.02s	remaining: 14.3s
# 13:	learn: 2200.8557645	total: 5.42s	remaining: 13.9s
# 14:	learn: 2143.4001512	total: 5.82s	remaining: 13.6s
# 15:	learn: 2093.5706902	total: 6.21s	remaining: 13.2s
# 16:	learn: 2044.3298956	total: 6.61s	remaining: 12.8s
# 17:	learn: 2002.6767636	total: 7.01s	remaining: 12.5s
# 18:	learn: 1966.3661904	total: 7.41s	remaining: 12.1s
# 19:	learn: 1936.3465244	total: 7.8s	remaining: 11.7s
# 20:	learn: 1910.9054236	total: 8.2s	remaining: 11.3s
# 21:	learn: 1888.0219200	total: 8.52s	remaining: 10.8s
# 22:	learn: 1867.6092090	total: 8.9s	remaining: 10.5s
# 23:	learn: 1848.5423591	total: 9.3s	remaining: 10.1s
# 24:	learn: 1833.6216723	total: 9.7s	remaining: 9.7s
# 25:	learn: 1819.4818942	total: 10.1s	remaining: 9.32s
# 26:	learn: 1807.2416301	total: 10.5s	remaining: 8.94s
# 27:	learn: 1796.2362133	total: 10.8s	remaining: 8.49s
# 28:	learn: 1786.0443513	total: 11.2s	remaining: 8.11s
# 29:	learn: 1777.2487571	total: 11.6s	remaining: 7.73s
# 30:	learn: 1769.5029431	total: 12s	remaining: 7.35s
# 31:	learn: 1760.0007232	total: 12.4s	remaining: 6.97s
# 32:	learn: 1753.7925486	total: 12.8s	remaining: 6.59s
# 33:	learn: 1747.6904956	total: 13.1s	remaining: 6.16s
# 34:	learn: 1738.0804497	total: 13.5s	remaining: 5.78s
# 35:	learn: 1728.8204015	total: 13.9s	remaining: 5.4s
# 36:	learn: 1721.5071731	total: 14.3s	remaining: 5.02s
# 37:	learn: 1715.0110768	total: 14.7s	remaining: 4.64s
# 38:	learn: 1708.7432917	total: 15.1s	remaining: 4.25s
# 39:	learn: 1700.9703544	total: 15.5s	remaining: 3.87s
# 40:	learn: 1696.1087121	total: 15.9s	remaining: 3.49s
# 41:	learn: 1692.7392281	total: 16.3s	remaining: 3.1s
# 42:	learn: 1688.0470377	total: 16.7s	remaining: 2.71s
# 43:	learn: 1684.0921928	total: 17.1s	remaining: 2.33s
# 44:	learn: 1680.8867732	total: 17.5s	remaining: 1.94s
# 45:	learn: 1678.5062285	total: 17.8s	remaining: 1.55s
# 46:	learn: 1676.1159823	total: 18.3s	remaining: 1.17s
# 47:	learn: 1673.8966062	total: 18.6s	remaining: 774ms
# 48:	learn: 1671.4627734	total: 19s	remaining: 387ms
# 49:	learn: 1667.8919946	total: 19.4s	remaining: 0us
# 0:	learn: 4336.3284929	total: 321ms	remaining: 15.7s
# 1:	learn: 4020.8998569	total: 720ms	remaining: 17.3s
# 2:	learn: 3748.2663088	total: 1.12s	remaining: 17.6s
# 3:	learn: 3504.6152482	total: 1.52s	remaining: 17.5s
# 4:	learn: 3288.5643202	total: 1.92s	remaining: 17.3s
# 5:	learn: 3096.9037030	total: 2.32s	remaining: 17s
# 6:	learn: 2929.2712889	total: 2.72s	remaining: 16.7s
# 7:	learn: 2779.9808838	total: 3.12s	remaining: 16.4s
# 8:	learn: 2643.2849895	total: 3.51s	remaining: 16s
# 9:	learn: 2530.0148348	total: 3.91s	remaining: 15.6s
# 10:	learn: 2428.8915640	total: 4.31s	remaining: 15.3s
# 11:	learn: 2339.7267139	total: 4.71s	remaining: 14.9s
# 12:	learn: 2263.5475134	total: 5.11s	remaining: 14.5s
# 13:	learn: 2194.4991221	total: 5.51s	remaining: 14.2s
# 14:	learn: 2137.6593761	total: 5.9s	remaining: 13.8s
# 15:	learn: 2086.1264418	total: 6.22s	remaining: 13.2s
# 16:	learn: 2042.3914138	total: 6.61s	remaining: 12.8s
# 17:	learn: 2003.2638677	total: 7.01s	remaining: 12.5s
# 18:	learn: 1969.7660324	total: 7.41s	remaining: 12.1s
# 19:	learn: 1940.5117680	total: 7.8s	remaining: 11.7s
# 20:	learn: 1916.5717853	total: 8.2s	remaining: 11.3s
# 21:	learn: 1893.4142815	total: 8.6s	remaining: 10.9s
# 22:	learn: 1874.6205340	total: 9s	remaining: 10.6s
# 23:	learn: 1857.6695354	total: 9.4s	remaining: 10.2s
# 24:	learn: 1843.1741746	total: 9.8s	remaining: 9.8s
# 25:	learn: 1827.1884068	total: 10.2s	remaining: 9.41s
# 26:	learn: 1814.5870148	total: 10.6s	remaining: 9.03s
# 27:	learn: 1803.9066709	total: 11s	remaining: 8.63s
# 28:	learn: 1792.1438391	total: 11.4s	remaining: 8.25s
# 29:	learn: 1781.9597225	total: 11.8s	remaining: 7.86s
# 30:	learn: 1772.2697470	total: 12.1s	remaining: 7.41s
# 31:	learn: 1763.6424019	total: 12.5s	remaining: 7.03s
# 32:	learn: 1757.9211035	total: 12.9s	remaining: 6.64s
# 33:	learn: 1748.8924855	total: 13.3s	remaining: 6.25s
# 34:	learn: 1740.3121811	total: 13.7s	remaining: 5.87s
# 35:	learn: 1733.8023619	total: 14.1s	remaining: 5.48s
# 36:	learn: 1726.2963496	total: 14.5s	remaining: 5.09s
# 37:	learn: 1719.3340606	total: 14.9s	remaining: 4.7s
# 38:	learn: 1714.7285252	total: 15.2s	remaining: 4.28s
# 39:	learn: 1709.1606222	total: 15.6s	remaining: 3.9s
# 40:	learn: 1704.8211211	total: 16s	remaining: 3.51s
# 41:	learn: 1700.5259868	total: 16.4s	remaining: 3.12s
# 42:	learn: 1696.9596376	total: 16.8s	remaining: 2.73s
# 43:	learn: 1693.9214596	total: 17.2s	remaining: 2.34s
# 44:	learn: 1690.0141954	total: 17.6s	remaining: 1.95s
# 45:	learn: 1687.0297888	total: 18s	remaining: 1.56s
# 46:	learn: 1684.2721965	total: 18.4s	remaining: 1.17s
# 47:	learn: 1680.0695861	total: 18.7s	remaining: 778ms
# 48:	learn: 1676.6360364	total: 19.1s	remaining: 389ms
# 49:	learn: 1674.2257629	total: 19.5s	remaining: 0us
# 0:	learn: 4333.9879670	total: 400ms	remaining: 19.6s
# 1:	learn: 4021.1256787	total: 798ms	remaining: 19.1s
# 2:	learn: 3746.0726667	total: 1.2s	remaining: 18.8s
# 3:	learn: 3499.1321175	total: 1.6s	remaining: 18.4s
# 4:	learn: 3279.2073000	total: 2s	remaining: 18s
# 5:	learn: 3084.4981043	total: 2.39s	remaining: 17.5s
# 6:	learn: 2917.1462946	total: 2.79s	remaining: 17.1s
# 7:	learn: 2768.0958330	total: 3.19s	remaining: 16.7s
# 8:	learn: 2637.9297363	total: 3.58s	remaining: 16.3s
# 9:	learn: 2526.2296878	total: 3.9s	remaining: 15.6s
# 10:	learn: 2422.9124329	total: 4.29s	remaining: 15.2s
# 11:	learn: 2335.7314256	total: 4.69s	remaining: 14.8s
# 12:	learn: 2257.4983565	total: 5.09s	remaining: 14.5s
# 13:	learn: 2190.4665790	total: 5.48s	remaining: 14.1s
# 14:	learn: 2131.2742445	total: 5.88s	remaining: 13.7s
# 15:	learn: 2079.5101616	total: 6.2s	remaining: 13.2s
# 16:	learn: 2036.1350333	total: 6.67s	remaining: 13s
# 17:	learn: 1994.8861468	total: 6.99s	remaining: 12.4s
# 18:	learn: 1961.3817473	total: 7.47s	remaining: 12.2s
# 19:	learn: 1933.0101790	total: 7.79s	remaining: 11.7s
# 20:	learn: 1907.6575777	total: 8.18s	remaining: 11.3s
# 21:	learn: 1885.1328243	total: 8.58s	remaining: 10.9s
# 22:	learn: 1861.7921994	total: 8.98s	remaining: 10.5s
# 23:	learn: 1843.8032747	total: 9.37s	remaining: 10.2s
# 24:	learn: 1828.2232272	total: 9.77s	remaining: 9.77s
# 25:	learn: 1814.7000786	total: 10.1s	remaining: 9.3s
# 26:	learn: 1801.3780407	total: 10.6s	remaining: 8.99s
# 27:	learn: 1787.9271069	total: 10.9s	remaining: 8.54s
# 28:	learn: 1777.0965650	total: 11.3s	remaining: 8.16s
# 29:	learn: 1767.9767195	total: 11.7s	remaining: 7.78s
# 30:	learn: 1758.1263437	total: 12.1s	remaining: 7.39s
# 31:	learn: 1749.2115172	total: 12.5s	remaining: 7.01s
# 32:	learn: 1741.8362913	total: 12.9s	remaining: 6.62s
# 33:	learn: 1734.6019856	total: 13.2s	remaining: 6.2s
# 34:	learn: 1726.6922193	total: 13.6s	remaining: 5.81s
# 35:	learn: 1719.1961443	total: 14s	remaining: 5.43s
# 36:	learn: 1712.9822089	total: 14.4s	remaining: 5.04s
# 37:	learn: 1707.5358820	total: 14.8s	remaining: 4.66s
# 38:	learn: 1701.6644317	total: 15.2s	remaining: 4.27s
# 39:	learn: 1695.9850004	total: 15.5s	remaining: 3.89s
# 40:	learn: 1689.9566371	total: 15.9s	remaining: 3.48s
# 41:	learn: 1686.7265375	total: 16.3s	remaining: 3.1s
# 42:	learn: 1681.6404133	total: 16.7s	remaining: 2.71s
# 43:	learn: 1678.4644448	total: 17.1s	remaining: 2.33s
# 44:	learn: 1675.4864125	total: 17.5s	remaining: 1.94s
# 45:	learn: 1671.2527080	total: 17.9s	remaining: 1.55s
# 46:	learn: 1666.6777299	total: 18.2s	remaining: 1.16s
# 47:	learn: 1661.7639213	total: 18.6s	remaining: 777ms
# 48:	learn: 1658.3440920	total: 19s	remaining: 389ms
# 49:	learn: 1654.5007540	total: 19.4s	remaining: 0us
# 0:	learn: 3062.2769260	total: 655ms	remaining: 32.1s
# 1:	learn: 2332.3523383	total: 1.26s	remaining: 30.1s
# 2:	learn: 2029.2776961	total: 1.77s	remaining: 27.8s
# 3:	learn: 1892.1048705	total: 2.36s	remaining: 27.1s
# 4:	learn: 1828.7014448	total: 2.96s	remaining: 26.6s
# 5:	learn: 1782.6297230	total: 3.46s	remaining: 25.4s
# 6:	learn: 1750.8855160	total: 3.96s	remaining: 24.3s
# 7:	learn: 1731.7325391	total: 4.55s	remaining: 23.9s
# 8:	learn: 1711.0761042	total: 5.07s	remaining: 23.1s
# 9:	learn: 1698.8809892	total: 5.65s	remaining: 22.6s
# 10:	learn: 1683.3605240	total: 6.16s	remaining: 21.8s
# 11:	learn: 1673.1418367	total: 6.74s	remaining: 21.4s
# 12:	learn: 1666.0502715	total: 7.25s	remaining: 20.6s
# 13:	learn: 1659.1418838	total: 7.75s	remaining: 19.9s
# 14:	learn: 1646.7666254	total: 8.35s	remaining: 19.5s
# 15:	learn: 1638.7425659	total: 8.85s	remaining: 18.8s
# 16:	learn: 1632.6131653	total: 9.35s	remaining: 18.2s
# 17:	learn: 1625.5779221	total: 9.95s	remaining: 17.7s
# 18:	learn: 1620.5980173	total: 10.4s	remaining: 17s
# 19:	learn: 1612.0670449	total: 11s	remaining: 16.6s
# 20:	learn: 1607.6765072	total: 11.5s	remaining: 15.9s
# 21:	learn: 1595.2571773	total: 12.1s	remaining: 15.4s
# 22:	learn: 1587.8898862	total: 12.6s	remaining: 14.8s
# 23:	learn: 1580.9832379	total: 13.2s	remaining: 14.3s
# 24:	learn: 1573.8054541	total: 13.7s	remaining: 13.7s
# 25:	learn: 1568.4280008	total: 14.3s	remaining: 13.2s
# 26:	learn: 1564.5845175	total: 14.8s	remaining: 12.6s
# 27:	learn: 1560.3994586	total: 15.3s	remaining: 12.1s
# 28:	learn: 1555.5960121	total: 15.9s	remaining: 11.5s
# 29:	learn: 1553.6116764	total: 16.4s	remaining: 11s
# 30:	learn: 1549.6011043	total: 17s	remaining: 10.4s
# 31:	learn: 1547.0074092	total: 17.5s	remaining: 9.86s
# 32:	learn: 1540.0165763	total: 18s	remaining: 9.29s
# 33:	learn: 1536.9721001	total: 18.6s	remaining: 8.76s
# 34:	learn: 1532.7590069	total: 19.1s	remaining: 8.2s
# 35:	learn: 1530.6827977	total: 19.6s	remaining: 7.63s
# 36:	learn: 1528.0442188	total: 20.2s	remaining: 7.11s
# 37:	learn: 1526.9219661	total: 20.7s	remaining: 6.54s
# 38:	learn: 1524.9534333	total: 21.2s	remaining: 5.99s
# 39:	learn: 1523.5535603	total: 21.8s	remaining: 5.45s
# 40:	learn: 1519.4813493	total: 22.3s	remaining: 4.9s
# 41:	learn: 1516.0781210	total: 22.9s	remaining: 4.36s
# 42:	learn: 1514.2916250	total: 23.4s	remaining: 3.81s
# 43:	learn: 1513.2356541	total: 24s	remaining: 3.27s
# 44:	learn: 1511.8166421	total: 24.5s	remaining: 2.72s
# 45:	learn: 1508.8383386	total: 25s	remaining: 2.17s
# 46:	learn: 1504.6408977	total: 25.6s	remaining: 1.63s
# 47:	learn: 1501.5730079	total: 26.1s	remaining: 1.09s
# 48:	learn: 1499.4248879	total: 26.7s	remaining: 545ms
# 49:	learn: 1499.2721489	total: 27.2s	remaining: 0us

# %% [markdown]
# We can print out the best hyperparameter settings for our model

# %%
print('Best score across all searched parameters', grid.best_score_)
print('Best parameters:', best_param)
# Out:
# Best score across all searched parameters -1609.1884105589986
# Best parameters: {'depth': 10, 'iterations': 50, 'l2_leaf_reg': 4, 'learning_rate': 0.5, 'loss_function': 'RMSE', 'random_seed': 12345}

# %% [markdown]
# We can now train our CatBoost regressor using the best hyperparameter settings got, get predictions, all while timing the processes

# %%
#CBR model tarining
CBR=CatBoostRegressor(depth=best_param['depth'],
                     iterations=best_param['iterations'],
                     l2_leaf_reg=best_param['l2_leaf_reg'],
                     learning_rate=best_param['learning_rate'],
                     loss_function='RMSE', random_seed=random_state)
# %time CBR.fit(f_train_gbm, t_train_gbm, cat_features=cat_feat, verbose=False, plot=False)
# Out:
# CPU times: user 26.8 s, sys: 1.64 s, total: 28.5 s
# Wall time: 30 s

# %%
#CBR model predictions
# %time CBR_pred=CBR.predict(f_test_gbm)
# Out:
# CPU times: user 280 ms, sys: 8.6 ms, total: 289 ms
# Wall time: 307 ms

# %% [markdown]
# RMSE calculation:

# %%
CBR_rmse=rmse(t_test_gbm, CBR_pred)
CBR_rmse
# Out:
# 1590.1999494650702

# %% [markdown]
# An RMSE of 1590. Much better than our baseline

# %% [markdown]
# ## LightGBM Regressor<a name='step3_5'></a>

# %% [markdown]
# This also doesn't require prior encoding. We will still be performing hyperparameter tuning similar to the way we did for CatBoost, except we will be dealing with different hyperparameters. One thing to note about LightGBM is that our categorical features have to be of the 'category' type before feeding it to LightGBM. It will not accept 'object' types or anything else. So we will need to do so both for the training set and the test set

# %%
#Converting all categorical variables to 'category' type
for c in cat_feat:
    f_train_gbm[c] = f_train_gbm[c].astype('category')

#LightGBM hyperparameter tuning
model=LGBMRegressor()
parameters={'num_leaves': [10, 20, 30],
           'learning_rate': [0.5, 0.1],
           'n_estimators': [10, 20],
           'random_state': [random_state],
           'objective': ['rmse']}
grid=GridSearchCV(estimator=model, param_grid=parameters, scoring=scorer, cv=3, n_jobs=-1)
grid.fit(f_train_gbm, t_train_gbm)
best_param=grid.best_params_
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# Let us get our best hyperparameter settings:

# %%
print('Best score across all searched parameters', grid.best_score_)
print('Best parameters:', best_param)
# Out:
# Best score across all searched parameters -1681.0490934534325
# Best parameters: {'learning_rate': 0.5, 'n_estimators': 20, 'num_leaves': 30, 'objective': 'rmse', 'random_state': 12345}

# %% [markdown]
# We will now train and test our LightGBM model using those hparameter settings, test the model, all while timing the processes

# %%
#LightGBM model training
lgbm=LGBMRegressor(learning_rate=0.5,
                  n_estimators=20,
                  num_leaves=30,
                  objective='rmse', random_state=random_state)
# %time lgbm.fit(f_train_gbm, t_train_gbm)
# Out:
# CPU times: user 4.36 s, sys: 14.3 ms, total: 4.37 s
# Wall time: 4.46 s
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.5, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=20, n_jobs=-1, num_leaves=30, objective='rmse',
#               random_state=12345, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
#convert test features to 'category' type
for c in cat_feat:
    f_test_gbm[c] = f_test_gbm[c].astype('category')

#LightGBM model predictions
# %time lgbm_pred=lgbm.predict(f_test_gbm)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# CPU times: user 225 ms, sys: 0 ns, total: 225 ms
# Wall time: 240 ms

# %% [markdown]
# RMSE calculation:

# %%
lgbm_rmse=rmse(t_test_gbm, lgbm_pred)
lgbm_rmse
# Out:
# 1664.1203426677855

# %% [markdown]
# RMSE of 1664.12. Much better than our baseline

# %% [markdown]
# # Model analysis<a name='step4'></a>

# %% [markdown]
# We can prepare a table showing the different models and their training and prediction times (in milliseconds) and RMSEs

# %%
index=['LR', 'DTR', 'RFR', 'CB', 'LGBM']
summary=pd.DataFrame(data={'training_time(ms)': [102, 1020, 76000, 30600, 20400],
                             'prediction_time(ms)': [6.73, 12.9, 1790, 265, 181],
                             'RMSE': [3319, 1855, 1527, 1590, 1664]},
                    index=index)
summary
# Out:
#       training_time(ms)  prediction_time(ms)  RMSE
# LR                  102                 6.73  3319
# DTR                1020                12.90  1855
# RFR               76000              1790.00  1527
# CB                30600               265.00  1590
# LGBM              20400               181.00  1664

# %% [markdown]
# Takeaways:
# 1. Linear Regression had the best training time (102 ms) while the worst goes to Random Forest (76000 ms)
# 2. Linear Regression had the best prediction time (6.73 ms) while the worst goes to Random Forest (1790 ms)
#
# (To be fair, we did train Random Forest with n_estimators=70 and max_depth=24. But generally, Random Forests take more time)
#
# 3. Random Forest had the best RMSE (1527) while the worst goes to Linear Regression (3319)

# %% [markdown]
# # Conclusion<a name='step6'></a>

# %% [markdown]
# We have successfully cleaned and prepared the data and used it to train models. Even though the Random Forest model has the highest RMSE (1527), the cost in terms of training and prediction time is very considerable. The CatBoost regressor takes less than half that amount of time and gets an RMSE of 1590, a difference of just 63 Euros. So we recommend the CatBoost model
